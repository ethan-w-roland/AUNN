# %% [markdown]
# # Setup

# %%
import random
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

from tqdm.notebook import tqdm
from matplotlib import pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

#deallocate all cuda memory
torch.cuda.empty_cache()

#print cuda memory
print(torch.cuda.memory_allocated())
# Out:
# cuda
# 0

# %% [markdown]
# # Causal-Masked MLP Mixer

# %%
#define a MLP Mixer based causal-language-model using weight masking

class CausalLinear(nn.Module):
    """
    A linear layer with a triangular (causal) mask applied to the weight matrix.
    This ensures each position i cannot use info from positions > i.
    """
    def __init__(self, in_dim: int, out_dim: int):
        
        super().__init__()

        if in_dim != out_dim:
            raise NotImplementedError("Only square matrices are supported.")

        # Standard weight + bias
        self.weight = nn.Parameter(torch.randn(in_dim, out_dim))
        self.bias = nn.Parameter(torch.zeros(out_dim))

        # triangular mask
        mask = torch.triu(torch.ones(in_dim, out_dim))
        self.register_buffer('mask', mask)

    def forward(self, x):
        """
        x shape: (batch, embed_dim, seq_len)
        """
        B, E, S = x.shape
        W = self.weight * self.mask    # elementwise multiply
        x_reshaped = x.reshape(B * E, S)  # (B*E, S)
        out = x_reshaped @ W           # (B*E, S)
        out = out + self.bias          # broadcast bias
        out = out.view(B, E, S)        # reshape back

        return out

class MixerBlock(nn.Module):
    
    def __init__(
        self,
        hidden_dim:int,
        seq_len:int,
        expansion_factor:int=2,
        dropout:float=0.1):

        super(MixerBlock, self).__init__()

        self.hidden_dim = hidden_dim
        self.seq_len = seq_len
        self.expansion_factor = expansion_factor

        #channel-norm
        self.channel_norm = nn.RMSNorm(hidden_dim)

        #channel-mixing layer
        self.channel_mixing_layer = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim * expansion_factor),
            nn.SiLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim * expansion_factor, hidden_dim)
        )

        #token-norm
        self.token_norm = nn.RMSNorm(hidden_dim)

        #token-mixing layer
        self.token_mixing_layer = nn.Sequential(
            CausalLinear(seq_len, seq_len),
            nn.SiLU(),
            nn.Dropout(dropout),
            CausalLinear(seq_len, seq_len)
        )

    def forward(self, x):

        res = x
        x = self.channel_norm(x)
        x = self.channel_mixing_layer(x)
        x = x + res

        res = x
        x = self.token_norm(x)
        x = x.transpose(1, 2)
        x = self.token_mixing_layer(x)
        x = x.transpose(1, 2)
        x = x + res

        return x

class MLPMixer(nn.Module):
    
    def __init__(
        self,
        vocab_size:int,
        hidden_dim:int,
        seq_len:int,
        num_blocks:int):

        super(MLPMixer, self).__init__()

        self.vocab_size = vocab_size
        self.hidden_dim = hidden_dim
        self.seq_len = seq_len
        self.num_blocks = num_blocks

        # Input Embedding
        self.input_layer = nn.Embedding(vocab_size, hidden_dim)

        # Mixer Blocks
        self.mixer_blocks = nn.ModuleList(
            [MixerBlock(hidden_dim, seq_len) for _ in range(num_blocks)]
        )

        # Output Layer
        self.output_layer = nn.Linear(hidden_dim, vocab_size, bias=False)

        # Tie input and output layer weights
        self.output_layer.weight = self.input_layer.weight

        # Initialize weights
        self._init_weights()

        # Define loss function
        self.loss_fn = nn.CrossEntropyLoss()

    def _init_weights(self):

        for m in self.modules():
            if isinstance(m, nn.Linear) or isinstance(m, CausalLinear):
                # Kaiming He initialization for Swish activation
                nn.init.kaiming_normal_(m.weight)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)

    def count_params(self):
        return sum(p.numel() for p in self.parameters() if p.requires_grad)

    def forward(self, x, labels=None):

        x = self.input_layer(x)
        for block in self.mixer_blocks:
            x = block(x)
        logits = self.output_layer(x)

        if not labels is None:

            logits = logits.view(-1, self.vocab_size)
            labels = labels.view(-1)
            loss = self.loss_fn(logits, labels)
            return loss, logits

        else:
            return logits

# %%
# Define a function to save the model checkpoint
def save_checkpoint(model, params, optimizer, losses, filename="checkpoint.pth"):
    
    checkpoint = {
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'losses': losses,
        'params':{}
    }

    keys = ['vocab_size', 'hidden_dim', 'seq_len', 'num_blocks']
    assert all(k in params for k in keys)
    for k in keys:
        checkpoint['params'][k] = params[k]

    torch.save(checkpoint, filename)
    print(f"Checkpoint saved with loss {losses[-1]:.4f}")

# %%
def load_checkpoint(filename="checkpoint.pth"):

    checkpoint = torch.load(filename, weights_only=True)
    
    params = checkpoint['params']
    print(params)
    model = MLPMixer(**params)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.to(device)
    
    optimizer = optim.AdamW(model.parameters())
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    
    losses = checkpoint['losses']

    print(f"Checkpoint loaded: loss {losses[-1]:.4f}")

    return model, optimizer, losses

# %% [markdown]
# ## Prepare Dataset

# %%
#load text
with open('shakespeare/data/train.txt', 'r', encoding='utf-8') as f:
    text = f.read()
print(len(text))

#get unique characters
all_chars = sorted(list(set(text)))
vocab_size = len(all_chars)
print(f"Unique characters: {vocab_size}")
# Out:
# 1115394
# Unique characters: 65

# %%
char2id = {ch: i for i, ch in enumerate(tqdm(all_chars))}
id2char = {i: ch for i, ch in enumerate(tqdm(all_chars))}
tokens = [char2id[ch] for ch in tqdm(text)]
# Out:
#   0%|          | 0/65 [00:00<?, ?it/s]
#   0%|          | 0/65 [00:00<?, ?it/s]
#   0%|          | 0/1115394 [00:00<?, ?it/s]

# %% [markdown]
# ## Train

# %%
# Hyperparameters
hidden_dim = 128  # Size of hidden layers
seq_len = 128
num_blocks = 6
batch_size = 32
num_epochs = 2000

# %%
pad_size = seq_len - (len(tokens) % seq_len) + 1 #we add one to account for x-y offset
pad = [char2id[' ']] * pad_size
train_data = torch.tensor(tokens + pad, dtype=torch.long).to(device)
print(len(train_data))
# Out:
# 1115521

# %%
#get index every seq_len, starting at idx 0
idx = list(range(0, len(train_data)-1, seq_len))
num_batches = len(idx) // batch_size
if len(idx) % batch_size != 0:
    num_batches += 1
print(num_batches)
# Out:
# 273

# %%
# Initialize the model
model = MLPMixer(vocab_size, hidden_dim, seq_len, num_blocks).to(device)
print(f"Model has {model.count_params():,} parameters")

# %%
lr = 1e-4
optimizer = optim.AdamW(model.parameters(), lr=lr)

# %%
losses = []
accuracies = []

# %%
model.train()

SHUFFLE_BATCHES = True
random.seed(42)

for epoch in tqdm(range(num_epochs)):
    print(f"EPOCH {epoch+1}/{num_epochs}")

    if SHUFFLE_BATCHES:
        random.shuffle(idx)

    batch_nums = list(range(num_batches))
    for i in batch_nums:
        
        batch_start = i * batch_size
        batch_end = min((i+1) * batch_size, len(idx))
        batch_idx = idx[batch_start:batch_end]

        # Get the batch data
        batch = torch.stack([train_data[i:i+seq_len+1] for i in batch_idx], dim=0)
        x = batch[:, :-1].contiguous()
        y = batch[:, 1:].contiguous()

        # Forward pass
        optimizer.zero_grad()
        loss, output = model(x, y)
        loss.backward()
        optimizer.step()

        losses.append(loss.item())

    avg_loss = sum(losses[-num_batches:]) / num_batches
    print(f"Average loss: {avg_loss:.4f}")

# %%
save_checkpoint(model, {
    'vocab_size': vocab_size,
    'hidden_dim': hidden_dim,
    'seq_len': seq_len,
    'num_blocks': num_blocks
}, optimizer, losses, filename="shakespeare/checkpoints/mixer/checkpoint_CLM.pth")

# %%
model, optimizer, losses = load_checkpoint("shakespeare/checkpoints/mixer/checkpoint_CLM.pth")
# Out:
# {'vocab_size': 65, 'hidden_dim': 128, 'seq_len': 128, 'num_blocks': 6}
# Checkpoint loaded: loss 2.5538

# %%
# Plot the loss curve

temp = []
for i in range(0, len(losses), num_batches):
    epoch = losses[i:i+num_batches]
    avg = np.mean(epoch)
    temp.append(avg)

plt.figure(figsize=(20, 6))
plt.plot(temp, label="Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.legend()
plt.show()

# %%
import torch
import torch.nn.functional as F

def evaluate(model, prompt, generation_length=100, seq_len=128):
    """
    Generates text from the model given a prompt.
    
    Args:
        model: The trained MLPMixer model.
        prompt (str): The prompt to condition generation on.
        generation_length (int): Number of characters to generate.
        seq_len (int): The sequence length the model expects.
        temperature (float): Temperature parameter for sampling.
    
    Returns:
        str: The prompt plus the generated text.
    """
    model.eval()  # Set model to evaluation mode
    # Convert prompt into a list of token ids
    tokens = [char2id[c] for c in prompt]
    
    # Autoregressive generation loop
    with torch.no_grad():
        for _ in range(generation_length):
            # Prepare the input context:
            # If the context is shorter than seq_len, pad to the left (using the token for space)
            if len(tokens) < seq_len:
                # pad with the space character (or any chosen pad token)
                padded = [char2id[' ']] * (seq_len - len(tokens)) + tokens
            else:
                padded = tokens[-seq_len:]
            
            # Convert to a tensor and add batch dimension
            x = torch.tensor(padded, dtype=torch.long, device=device).unsqueeze(0)  # shape (1, seq_len)
            
            # Get logits from the model; output shape is (1, seq_len, vocab_size)
            logits = model(x)

            predictions = torch.argmax(logits, dim=-1)

            #intermediate string output
            # temp = [id2char[t] for t in predictions[0].tolist()]
            # print(''.join(temp))

            next_token = predictions[0][-1].item()
            tokens.append(next_token)
    
    # Convert the list of tokens back to a string
    generated_text = ''.join([id2char[t] for t in tokens])
    return generated_text

# Example usage:
prompt = "We are accounted poor citizens, the patricians good. What authority surfeits on would relieve us: if they would yield us but the superfluity, while it were wholesome, we might guess they relieved us humanely;"
print(len(prompt))
generated = evaluate(model, prompt, generation_length=100, seq_len=seq_len)
print("Generated text:")
print(generated)
# Out:
# 208
# Generated text:
# We are accounted poor citizens, the patricians good. What authority surfeits on would relieve us: if they would yield us but the superfluity, while it were wholesome, we might guess they relieved us humanely; t the the he the and t the t the the an t the t t t t t t the there and the t an and the s the the

# %% [markdown]
# # Toeplitz Causal MLP Mixer

# %%
#define a MLP Mixer based causal-language-model using weight masking

class ToeplitzCausalLinear(nn.Module):
    """
    A linear layer with a triangular (causal) mask applied to the weight matrix.
    This ensures each position i cannot use info from positions > i.
    """
    def __init__(self, dim: int):
        
        super().__init__()

        # Standard weight + bias
        self.weight = nn.Parameter(torch.randn(1, dim))
        self.bias = nn.Parameter(torch.zeros(dim))

    def vector_to_matrix(self, v):
        """
        Given a vector v of shape (m,), returns an (m x m) matrix M
        where M[i, j] = v[j - i] if j >= i, and 0 otherwise.
        
        For example, if v = [a, b, c, d] then M will be:
        
        [ a  b  c  d ]
        [ 0  a  b  c ]
        [ 0  0  a  b ]
        [ 0  0  0  a ]
        """
        v = v.reshape(-1)  # Ensure v is a 1D tensor
        m = v.shape[0]
        # Create index grids for rows and columns
        i, j = torch.meshgrid(torch.arange(m, device=v.device),
                                torch.arange(m, device=v.device), 
                                indexing='ij')
        # j - i gives the offset into v. When j < i, we want a 0.
        M = torch.where(j >= i, v[j - i], torch.zeros(m, m, device=v.device, dtype=v.dtype))
        return M

    def forward(self, x):
        """
        x shape: (batch, embed_dim, seq_len)
        """
        B, E, S = x.shape
        W = self.vector_to_matrix(self.weight)
        x_reshaped = x.reshape(B * E, S)  # (B*E, S)
        out = x_reshaped @ W           # (B*E, S)
        out = out + self.bias          # broadcast bias
        out = out.view(B, E, S)        # reshape back

        return out

class MixerBlock(nn.Module):
    
    def __init__(
        self,
        hidden_dim:int,
        seq_len:int,
        expansion_factor:int=2,
        dropout:float=0.1):

        super(MixerBlock, self).__init__()

        self.hidden_dim = hidden_dim
        self.seq_len = seq_len
        self.expansion_factor = expansion_factor

        #channel-norm
        self.channel_norm = nn.RMSNorm(hidden_dim)

        #channel-mixing layer
        self.channel_mixing_layer = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim * expansion_factor),
            nn.SiLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim * expansion_factor, hidden_dim)
        )

        #token-norm
        self.token_norm = nn.RMSNorm(hidden_dim)

        #token-mixing layer
        self.token_mixing_layer = nn.Sequential(
            ToeplitzCausalLinear(seq_len),
            nn.SiLU(),
            nn.Dropout(dropout),
            ToeplitzCausalLinear(seq_len)
        )

    def forward(self, x):

        res = x
        x = self.channel_norm(x)
        x = self.channel_mixing_layer(x)
        x = x + res

        res = x
        x = self.token_norm(x)
        x = x.transpose(1, 2)
        x = self.token_mixing_layer(x)
        x = x.transpose(1, 2)
        x = x + res

        return x

class MLPMixer(nn.Module):
    
    def __init__(
        self,
        vocab_size:int,
        hidden_dim:int,
        seq_len:int,
        num_blocks:int):

        super(MLPMixer, self).__init__()

        self.vocab_size = vocab_size
        self.hidden_dim = hidden_dim
        self.seq_len = seq_len
        self.num_blocks = num_blocks

        # Input Embedding
        self.input_layer = nn.Embedding(vocab_size, hidden_dim)

        # Mixer Blocks
        self.mixer_blocks = nn.ModuleList(
            [MixerBlock(hidden_dim, seq_len) for _ in range(num_blocks)]
        )

        # Output Layer
        self.output_layer = nn.Linear(hidden_dim, vocab_size, bias=False)

        # Tie input and output layer weights
        self.output_layer.weight = self.input_layer.weight

        # Initialize weights
        self._init_weights()

        # Define loss function
        self.loss_fn = nn.CrossEntropyLoss()

    def _init_weights(self):

        for m in self.modules():
            if isinstance(m, nn.Linear) or isinstance(m, ToeplitzCausalLinear):
                # Kaiming He initialization for Swish activation
                nn.init.kaiming_normal_(m.weight)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)

    def count_params(self):
        return sum(p.numel() for p in self.parameters() if p.requires_grad)

    def forward(self, x, labels=None):

        x = self.input_layer(x)
        for block in self.mixer_blocks:
            x = block(x)
        logits = self.output_layer(x)

        if not labels is None:

            logits = logits.view(-1, self.vocab_size)
            labels = labels.view(-1)
            loss = self.loss_fn(logits, labels)
            return loss, logits

        else:
            return logits

# %%
# Define a function to save the model checkpoint
def save_checkpoint(model, params, optimizer, losses, filename="checkpoint.pth"):
    
    checkpoint = {
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'losses': losses,
        'params':{}
    }

    keys = ['vocab_size', 'hidden_dim', 'seq_len', 'num_blocks']
    assert all(k in params for k in keys)
    for k in keys:
        checkpoint['params'][k] = params[k]

    torch.save(checkpoint, filename)
    print(f"Checkpoint saved with loss {losses[-1]:.4f}")

# %%
def load_checkpoint(filename="checkpoint.pth"):

    checkpoint = torch.load(filename, weights_only=True)
    
    params = checkpoint['params']
    print(params)
    model = MLPMixer(**params)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.to(device)
    
    optimizer = optim.AdamW(model.parameters())
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    
    losses = checkpoint['losses']

    print(f"Checkpoint loaded: loss {losses[-1]:.4f}")

    return model, optimizer, losses

# %% [markdown]
# ## Prepare Dataset

# %%
#load text
with open('shakespeare/data/train.txt', 'r', encoding='utf-8') as f:
    text = f.read()
print(len(text))

# #load text
# with open('mixer/TinyStories-train.txt', 'r', encoding='utf-8') as f:
#     text = f.read()
# print(len(text))

#get unique characters
all_chars = sorted(list(set(text)))
vocab_size = len(all_chars)
print(f"Unique characters: {vocab_size}")
# Out:
# 1115394
# Unique characters: 65

# %%
char2id = {ch: i for i, ch in enumerate(tqdm(all_chars))}
id2char = {i: ch for i, ch in enumerate(tqdm(all_chars))}
tokens = [char2id[ch] for ch in tqdm(text)]
# Out:
#   0%|          | 0/65 [00:00<?, ?it/s]
#   0%|          | 0/65 [00:00<?, ?it/s]
#   0%|          | 0/1115394 [00:00<?, ?it/s]

# %% [markdown]
# ## Train

# %%
# Hyperparameters
hidden_dim = 512  # Size of hidden layers
seq_len = 512
num_blocks = 6
batch_size = 32
num_epochs = 2000

# %%
pad_size = seq_len - (len(tokens) % seq_len) + 1 #we add one to account for x->y next-token-pred offset
pad = [char2id[' ']] * pad_size
train_data = torch.tensor(tokens + pad, dtype=torch.long).to(device)
print(len(train_data))
# Out:
# 1115649

# %%
#get index every seq_len, starting at idx 0
idx = list(range(0, len(train_data)-1, seq_len))
num_batches = len(idx) // batch_size
if len(idx) % batch_size != 0:
    num_batches += 1
print(num_batches)
# Out:
# 69

# %%
# Initialize the model
model = MLPMixer(vocab_size, hidden_dim, seq_len, num_blocks).to(device)
print(f"Model has {model.count_params():,} parameters")
# Out:
# Model has 6,352,384 parameters

# %%
lr = 1e-4
optimizer = optim.AdamW(model.parameters(), lr=lr)

# %%
losses = []
accuracies = []

# %%
model.train()

SHUFFLE_BATCHES = True
random.seed(42)

for epoch in tqdm(range(num_epochs)):
    print(f"EPOCH {epoch+1}/{num_epochs}")

    if SHUFFLE_BATCHES:
        random.shuffle(idx)

    batch_nums = list(range(num_batches))
    for i in batch_nums:
        
        batch_start = i * batch_size
        batch_end = min((i+1) * batch_size, len(idx))
        batch_idx = idx[batch_start:batch_end]

        # Get the batch data
        batch = torch.stack([train_data[i:i+seq_len+1] for i in batch_idx], dim=0)
        x = batch[:, :-1].contiguous()
        y = batch[:, 1:].contiguous()

        # Forward pass
        optimizer.zero_grad()
        loss, output = model(x, y)
        loss.backward()
        optimizer.step()

        losses.append(loss.item())

    avg_loss = sum(losses[-num_batches:]) / num_batches
    print(f"Average loss: {avg_loss:.4f}")
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# EPOCH 1/2000
# Average loss: 4.5805
# EPOCH 2/2000
# Average loss: 3.1433
# EPOCH 3/2000
# Average loss: 2.8725
# EPOCH 4/2000
# Average loss: 2.7542
# EPOCH 5/2000
# Average loss: 2.6854
# EPOCH 6/2000
# Average loss: 2.6448
# EPOCH 7/2000
# Average loss: 2.6142
# EPOCH 8/2000
# Average loss: 2.5938
# EPOCH 9/2000
# Average loss: 2.5770
# EPOCH 10/2000
# Average loss: 2.5654
# EPOCH 11/2000
# Average loss: 2.5533
# EPOCH 12/2000
# Average loss: 2.5433
# EPOCH 13/2000
# Average loss: 2.5356
# EPOCH 14/2000
# Average loss: 2.5278
# EPOCH 15/2000
# Average loss: 2.5236
# EPOCH 16/2000
# Average loss: 2.5201
# EPOCH 17/2000
# Average loss: 2.5155
# EPOCH 18/2000
# Average loss: 2.5102
# EPOCH 19/2000
# Average loss: 2.5090
# EPOCH 20/2000
# Average loss: 2.5050
# EPOCH 21/2000
# Average loss: 2.5023
# EPOCH 22/2000
# Average loss: 2.5004
# EPOCH 23/2000
# Average loss: 2.4974
# EPOCH 24/2000
# Average loss: 2.4941
# EPOCH 25/2000
# Average loss: 2.4930
# EPOCH 26/2000
# Average loss: 2.4921
# EPOCH 27/2000
# Average loss: 2.4909
# EPOCH 28/2000
# Average loss: 2.4870
# EPOCH 29/2000
# Average loss: 2.4846
# EPOCH 30/2000
# Average loss: 2.4828
# EPOCH 31/2000
# Average loss: 2.4809
# EPOCH 32/2000
# Average loss: 2.4794
# EPOCH 33/2000
# Average loss: 2.4760
# EPOCH 34/2000
# Average loss: 2.4730
# EPOCH 35/2000
# Average loss: 2.4706
# EPOCH 36/2000
# Average loss: 2.4663
# EPOCH 37/2000
# Average loss: 2.4606
# EPOCH 38/2000
# Average loss: 2.4551
# EPOCH 39/2000
# Average loss: 2.4473
# EPOCH 40/2000
# Average loss: 2.4383
# EPOCH 41/2000
# Average loss: 2.4278
# EPOCH 42/2000
# Average loss: 2.4133
# EPOCH 43/2000
# Average loss: 2.3925
# EPOCH 44/2000
# Average loss: 2.3710
# EPOCH 45/2000
# Average loss: 2.3439
# EPOCH 46/2000
# Average loss: 2.3108
# EPOCH 47/2000
# Average loss: 2.2741
# EPOCH 48/2000
# Average loss: 2.2335
# EPOCH 49/2000
# Average loss: 2.1885
# EPOCH 50/2000
# Average loss: 2.1499
# EPOCH 51/2000
# Average loss: 2.1140
# EPOCH 52/2000
# Average loss: 2.0814
# EPOCH 53/2000
# Average loss: 2.0485
# EPOCH 54/2000
# Average loss: 2.0185
# EPOCH 55/2000
# Average loss: 1.9940
# EPOCH 56/2000
# Average loss: 1.9659
# EPOCH 57/2000
# Average loss: 1.9452
# EPOCH 58/2000
# Average loss: 1.9211
# EPOCH 59/2000
# Average loss: 1.9006
# EPOCH 60/2000
# Average loss: 1.8815
# EPOCH 61/2000
# Average loss: 1.8602
# EPOCH 62/2000
# Average loss: 1.8438
# EPOCH 63/2000
# Average loss: 1.8246
# EPOCH 64/2000
# Average loss: 1.8085
# EPOCH 65/2000
# Average loss: 1.7942
# EPOCH 66/2000
# Average loss: 1.7817
# EPOCH 67/2000
# Average loss: 1.7675
# EPOCH 68/2000
# Average loss: 1.7524
# EPOCH 69/2000
# Average loss: 1.7420
# EPOCH 70/2000
# Average loss: 1.7287
# EPOCH 71/2000
# Average loss: 1.7162
# EPOCH 72/2000
# Average loss: 1.7050
# EPOCH 73/2000
# Average loss: 1.6934
# EPOCH 74/2000
# Average loss: 1.6855
# EPOCH 75/2000
# Average loss: 1.6729
# EPOCH 76/2000
# Average loss: 1.6643
# EPOCH 77/2000
# Average loss: 1.6563
# EPOCH 78/2000
# Average loss: 1.6424
# EPOCH 79/2000
# Average loss: 1.6365
# EPOCH 80/2000
# Average loss: 1.6263
# EPOCH 81/2000
# Average loss: 1.6186
# EPOCH 82/2000
# Average loss: 1.6097
# EPOCH 83/2000
# Average loss: 1.6036
# EPOCH 84/2000
# Average loss: 1.5925
# EPOCH 85/2000
# Average loss: 1.5870
# EPOCH 86/2000
# Average loss: 1.5764
# EPOCH 87/2000
# Average loss: 1.5680
# EPOCH 88/2000
# Average loss: 1.5603
# EPOCH 89/2000
# Average loss: 1.5540
# EPOCH 90/2000
# Average loss: 1.5462
# EPOCH 91/2000
# Average loss: 1.5398
# EPOCH 92/2000
# Average loss: 1.5332
# EPOCH 93/2000
# Average loss: 1.5276
# EPOCH 94/2000
# Average loss: 1.5205
# EPOCH 95/2000
# Average loss: 1.5156
# EPOCH 96/2000
# Average loss: 1.5106
# EPOCH 97/2000
# Average loss: 1.5039
# EPOCH 98/2000
# Average loss: 1.4966
# EPOCH 99/2000
# Average loss: 1.4915
# EPOCH 100/2000
# Average loss: 1.4849
# EPOCH 101/2000
# Average loss: 1.4798
# EPOCH 102/2000
# Average loss: 1.4751
# EPOCH 103/2000
# Average loss: 1.4704
# EPOCH 104/2000
# Average loss: 1.4637
# EPOCH 105/2000
# Average loss: 1.4593
# EPOCH 106/2000
# Average loss: 1.4540
# EPOCH 107/2000
# Average loss: 1.4476
# EPOCH 108/2000
# Average loss: 1.4443
# EPOCH 109/2000
# Average loss: 1.4402
# EPOCH 110/2000
# Average loss: 1.4359
# EPOCH 111/2000
# Average loss: 1.4319
# EPOCH 112/2000
# Average loss: 1.4260
# EPOCH 113/2000
# Average loss: 1.4208
# EPOCH 114/2000
# Average loss: 1.4168
# EPOCH 115/2000
# Average loss: 1.4138
# EPOCH 116/2000
# Average loss: 1.4085
# EPOCH 117/2000
# Average loss: 1.4050
# EPOCH 118/2000
# Average loss: 1.3985
# EPOCH 119/2000
# Average loss: 1.3945
# EPOCH 120/2000
# Average loss: 1.3913
# EPOCH 121/2000
# Average loss: 1.3887
# EPOCH 122/2000
# Average loss: 1.3836
# EPOCH 123/2000
# Average loss: 1.3822
# EPOCH 124/2000
# Average loss: 1.3774
# EPOCH 125/2000
# Average loss: 1.3737
# EPOCH 126/2000
# Average loss: 1.3685
# EPOCH 127/2000
# Average loss: 1.3649
# EPOCH 128/2000
# Average loss: 1.3638
# EPOCH 129/2000
# Average loss: 1.3602
# EPOCH 130/2000
# Average loss: 1.3567
# EPOCH 131/2000
# Average loss: 1.3532
# EPOCH 132/2000
# Average loss: 1.3506
# EPOCH 133/2000
# Average loss: 1.3455
# EPOCH 134/2000
# Average loss: 1.3402
# EPOCH 135/2000
# Average loss: 1.3387
# EPOCH 136/2000
# Average loss: 1.3358
# EPOCH 137/2000
# Average loss: 1.3318
# EPOCH 138/2000
# Average loss: 1.3277
# EPOCH 139/2000
# Average loss: 1.3252
# EPOCH 140/2000
# Average loss: 1.3222
# EPOCH 141/2000
# Average loss: 1.3177
# EPOCH 142/2000
# Average loss: 1.3179
# EPOCH 143/2000
# Average loss: 1.3142
# EPOCH 144/2000
# Average loss: 1.3106
# EPOCH 145/2000
# Average loss: 1.3069
# EPOCH 146/2000
# Average loss: 1.3031
# EPOCH 147/2000
# Average loss: 1.2997
# EPOCH 148/2000
# Average loss: 1.2971
# EPOCH 149/2000
# Average loss: 1.2928
# EPOCH 150/2000
# Average loss: 1.2890
# EPOCH 151/2000
# Average loss: 1.2878
# EPOCH 152/2000
# Average loss: 1.2846
# EPOCH 153/2000
# Average loss: 1.2805
# EPOCH 154/2000
# Average loss: 1.2788
# EPOCH 155/2000
# Average loss: 1.2777
# EPOCH 156/2000
# Average loss: 1.2743
# EPOCH 157/2000
# Average loss: 1.2714
# EPOCH 158/2000
# Average loss: 1.2697
# EPOCH 159/2000
# Average loss: 1.2668
# EPOCH 160/2000
# Average loss: 1.2628
# EPOCH 161/2000
# Average loss: 1.2591
# EPOCH 162/2000
# Average loss: 1.2570
# EPOCH 163/2000
# Average loss: 1.2524
# EPOCH 164/2000
# Average loss: 1.2512
# EPOCH 165/2000
# Average loss: 1.2480
# EPOCH 166/2000
# Average loss: 1.2442
# EPOCH 167/2000
# Average loss: 1.2429
# EPOCH 168/2000
# Average loss: 1.2396
# EPOCH 169/2000
# Average loss: 1.2351
# EPOCH 170/2000
# Average loss: 1.2329
# EPOCH 171/2000
# Average loss: 1.2320
# EPOCH 172/2000
# Average loss: 1.2277
# EPOCH 173/2000
# Average loss: 1.2251
# EPOCH 174/2000
# Average loss: 1.2226
# EPOCH 175/2000
# Average loss: 1.2187
# EPOCH 176/2000
# Average loss: 1.2188
# EPOCH 177/2000
# Average loss: 1.2134
# EPOCH 178/2000
# Average loss: 1.2132
# EPOCH 179/2000
# Average loss: 1.2093
# EPOCH 180/2000
# Average loss: 1.2054
# EPOCH 181/2000
# Average loss: 1.2036
# EPOCH 182/2000
# Average loss: 1.2005
# EPOCH 183/2000
# Average loss: 1.1959
# EPOCH 184/2000
# Average loss: 1.1942
# EPOCH 185/2000
# Average loss: 1.1913
# EPOCH 186/2000
# Average loss: 1.1901
# EPOCH 187/2000
# Average loss: 1.1846
# EPOCH 188/2000
# Average loss: 1.1835
# EPOCH 189/2000
# Average loss: 1.1817
# EPOCH 190/2000
# Average loss: 1.1782
# EPOCH 191/2000
# Average loss: 1.1753
# EPOCH 192/2000
# Average loss: 1.1716
# EPOCH 193/2000
# Average loss: 1.1690
# EPOCH 194/2000
# Average loss: 1.1666
# EPOCH 195/2000
# Average loss: 1.1642
# EPOCH 196/2000
# Average loss: 1.1625
# EPOCH 197/2000
# Average loss: 1.1568
# EPOCH 198/2000
# Average loss: 1.1551
# EPOCH 199/2000
# Average loss: 1.1518
# EPOCH 200/2000
# Average loss: 1.1498
# EPOCH 201/2000
# Average loss: 1.1459
# EPOCH 202/2000
# Average loss: 1.1459
# EPOCH 203/2000
# Average loss: 1.1412
# EPOCH 204/2000
# Average loss: 1.1372
# EPOCH 205/2000
# Average loss: 1.1348
# EPOCH 206/2000
# Average loss: 1.1330
# EPOCH 207/2000
# Average loss: 1.1280
# EPOCH 208/2000
# Average loss: 1.1271
# EPOCH 209/2000
# Average loss: 1.1256
# EPOCH 210/2000
# Average loss: 1.1202
# EPOCH 211/2000
# Average loss: 1.1182
# EPOCH 212/2000
# Average loss: 1.1150
# EPOCH 213/2000
# Average loss: 1.1138
# EPOCH 214/2000
# Average loss: 1.1102
# EPOCH 215/2000
# Average loss: 1.1088
# EPOCH 216/2000
# Average loss: 1.1056
# EPOCH 217/2000
# Average loss: 1.1012
# EPOCH 218/2000
# Average loss: 1.0992
# EPOCH 219/2000
# Average loss: 1.0964
# EPOCH 220/2000
# Average loss: 1.0931
# EPOCH 221/2000
# Average loss: 1.0921
# EPOCH 222/2000
# Average loss: 1.0863
# EPOCH 223/2000
# Average loss: 1.0829
# EPOCH 224/2000
# Average loss: 1.0813
# EPOCH 225/2000
# Average loss: 1.0795
# EPOCH 226/2000
# Average loss: 1.0774
# EPOCH 227/2000
# Average loss: 1.0744
# EPOCH 228/2000
# Average loss: 1.0712
# EPOCH 229/2000
# Average loss: 1.0674
# EPOCH 230/2000
# Average loss: 1.0635
# EPOCH 231/2000
# Average loss: 1.0621
# EPOCH 232/2000
# Average loss: 1.0584
# EPOCH 233/2000
# Average loss: 1.0557
# EPOCH 234/2000
# Average loss: 1.0534
# EPOCH 235/2000
# Average loss: 1.0511
# EPOCH 236/2000
# Average loss: 1.0468
# EPOCH 237/2000
# Average loss: 1.0453
# EPOCH 238/2000
# Average loss: 1.0410
# EPOCH 239/2000
# Average loss: 1.0392
# EPOCH 240/2000
# Average loss: 1.0372
# EPOCH 241/2000
# Average loss: 1.0350
# EPOCH 242/2000
# Average loss: 1.0318
# EPOCH 243/2000
# Average loss: 1.0275
# EPOCH 244/2000
# Average loss: 1.0257
# EPOCH 245/2000
# Average loss: 1.0217
# EPOCH 246/2000
# Average loss: 1.0199
# EPOCH 247/2000
# Average loss: 1.0170
# EPOCH 248/2000
# Average loss: 1.0145
# EPOCH 249/2000
# Average loss: 1.0103
# EPOCH 250/2000
# Average loss: 1.0075
# EPOCH 251/2000
# Average loss: 1.0050
# EPOCH 252/2000
# Average loss: 1.0028
# EPOCH 253/2000
# Average loss: 1.0001
# EPOCH 254/2000
# Average loss: 0.9980
# EPOCH 255/2000
# Average loss: 0.9956
# EPOCH 256/2000
# Average loss: 0.9915
# EPOCH 257/2000
# Average loss: 0.9887
# EPOCH 258/2000
# Average loss: 0.9844
# EPOCH 259/2000
# Average loss: 0.9817
# EPOCH 260/2000
# Average loss: 0.9816
# EPOCH 261/2000
# Average loss: 0.9773
# EPOCH 262/2000
# Average loss: 0.9746
# EPOCH 263/2000
# Average loss: 0.9714
# EPOCH 264/2000
# Average loss: 0.9683
# EPOCH 265/2000
# Average loss: 0.9680
# EPOCH 266/2000
# Average loss: 0.9645
# EPOCH 267/2000
# Average loss: 0.9618
# EPOCH 268/2000
# Average loss: 0.9604
# EPOCH 269/2000
# Average loss: 0.9565
# EPOCH 270/2000
# Average loss: 0.9527
# EPOCH 271/2000
# Average loss: 0.9507
# EPOCH 272/2000
# Average loss: 0.9484
# EPOCH 273/2000
# Average loss: 0.9455
# EPOCH 274/2000
# Average loss: 0.9431
# EPOCH 275/2000
# Average loss: 0.9388
# EPOCH 276/2000
# Average loss: 0.9373
# EPOCH 277/2000
# Average loss: 0.9361
# EPOCH 278/2000
# Average loss: 0.9320
# EPOCH 279/2000
# Average loss: 0.9294
# EPOCH 280/2000
# Average loss: 0.9271
# EPOCH 281/2000
# Average loss: 0.9234
# EPOCH 282/2000
# Average loss: 0.9216
# EPOCH 283/2000
# Average loss: 0.9190
# EPOCH 284/2000
# Average loss: 0.9159
# EPOCH 285/2000
# Average loss: 0.9133
# EPOCH 286/2000
# Average loss: 0.9102
# EPOCH 287/2000
# Average loss: 0.9079
# EPOCH 288/2000
# Average loss: 0.9047
# EPOCH 289/2000
# Average loss: 0.9029
# EPOCH 290/2000
# Average loss: 0.8984
# EPOCH 291/2000
# Average loss: 0.8968
# EPOCH 292/2000
# Average loss: 0.8955
# EPOCH 293/2000
# Average loss: 0.8937
# EPOCH 294/2000
# Average loss: 0.8902
# EPOCH 295/2000
# Average loss: 0.8879
# EPOCH 296/2000
# Average loss: 0.8843
# EPOCH 297/2000
# Average loss: 0.8815
# EPOCH 298/2000
# Average loss: 0.8791
# EPOCH 299/2000
# Average loss: 0.8766
# EPOCH 300/2000
# Average loss: 0.8731
# EPOCH 301/2000
# Average loss: 0.8710
# EPOCH 302/2000
# Average loss: 0.8689
# EPOCH 303/2000
# Average loss: 0.8670
# EPOCH 304/2000
# Average loss: 0.8633
# EPOCH 305/2000
# Average loss: 0.8625
# EPOCH 306/2000
# Average loss: 0.8589
# EPOCH 307/2000
# Average loss: 0.8571
# EPOCH 308/2000
# Average loss: 0.8542
# EPOCH 309/2000
# Average loss: 0.8519
# EPOCH 310/2000
# Average loss: 0.8487
# EPOCH 311/2000
# Average loss: 0.8478
# EPOCH 312/2000
# Average loss: 0.8438
# EPOCH 313/2000
# Average loss: 0.8426
# EPOCH 314/2000
# Average loss: 0.8386
# EPOCH 315/2000
# Average loss: 0.8385
# EPOCH 316/2000
# Average loss: 0.8352
# EPOCH 317/2000
# Average loss: 0.8334
# EPOCH 318/2000
# Average loss: 0.8299
# EPOCH 319/2000
# Average loss: 0.8289
# EPOCH 320/2000
# Average loss: 0.8263
# EPOCH 321/2000
# Average loss: 0.8237
# EPOCH 322/2000
# Average loss: 0.8208
# EPOCH 323/2000
# Average loss: 0.8185
# EPOCH 324/2000
# Average loss: 0.8169
# EPOCH 325/2000
# Average loss: 0.8148
# EPOCH 326/2000
# Average loss: 0.8127
# EPOCH 327/2000
# Average loss: 0.8084
# EPOCH 328/2000
# Average loss: 0.8059
# EPOCH 329/2000
# Average loss: 0.8045
# EPOCH 330/2000
# Average loss: 0.8023
# EPOCH 331/2000
# Average loss: 0.8001
# EPOCH 332/2000
# Average loss: 0.7975
# EPOCH 333/2000
# Average loss: 0.7968
# EPOCH 334/2000
# Average loss: 0.7942
# EPOCH 335/2000
# Average loss: 0.7910
# EPOCH 336/2000
# Average loss: 0.7880
# EPOCH 337/2000
# Average loss: 0.7872
# EPOCH 338/2000
# Average loss: 0.7834
# EPOCH 339/2000
# Average loss: 0.7822
# EPOCH 340/2000
# Average loss: 0.7798
# EPOCH 341/2000
# Average loss: 0.7768
# EPOCH 342/2000
# Average loss: 0.7760
# EPOCH 343/2000
# Average loss: 0.7731
# EPOCH 344/2000
# Average loss: 0.7719
# EPOCH 345/2000
# Average loss: 0.7678
# EPOCH 346/2000
# Average loss: 0.7664
# EPOCH 347/2000
# Average loss: 0.7637
# EPOCH 348/2000
# Average loss: 0.7628
# EPOCH 349/2000
# Average loss: 0.7590
# EPOCH 350/2000
# Average loss: 0.7570
# EPOCH 351/2000
# Average loss: 0.7552
# EPOCH 352/2000
# Average loss: 0.7527
# EPOCH 353/2000
# Average loss: 0.7500
# EPOCH 354/2000
# Average loss: 0.7481
# EPOCH 355/2000
# Average loss: 0.7476
# EPOCH 356/2000
# Average loss: 0.7463
# EPOCH 357/2000
# Average loss: 0.7439
# EPOCH 358/2000
# Average loss: 0.7411
# EPOCH 359/2000
# Average loss: 0.7394
# EPOCH 360/2000
# Average loss: 0.7382
# EPOCH 361/2000
# Average loss: 0.7350
# EPOCH 362/2000
# Average loss: 0.7332
# EPOCH 363/2000
# Average loss: 0.7312
# EPOCH 364/2000
# Average loss: 0.7301
# EPOCH 365/2000
# Average loss: 0.7277
# EPOCH 366/2000
# Average loss: 0.7245
# EPOCH 367/2000
# Average loss: 0.7227
# EPOCH 368/2000
# Average loss: 0.7201
# EPOCH 369/2000
# Average loss: 0.7173
# EPOCH 370/2000
# Average loss: 0.7162
# EPOCH 371/2000
# Average loss: 0.7156
# EPOCH 372/2000
# Average loss: 0.7118
# EPOCH 373/2000
# Average loss: 0.7116
# EPOCH 374/2000
# Average loss: 0.7078
# EPOCH 375/2000
# Average loss: 0.7071
# EPOCH 376/2000
# Average loss: 0.7059
# EPOCH 377/2000
# Average loss: 0.7037
# EPOCH 378/2000
# Average loss: 0.6996
# EPOCH 379/2000
# Average loss: 0.6996
# EPOCH 380/2000
# Average loss: 0.6983
# EPOCH 381/2000
# Average loss: 0.6958
# EPOCH 382/2000
# Average loss: 0.6951
# EPOCH 383/2000
# Average loss: 0.6919
# EPOCH 384/2000
# Average loss: 0.6900
# EPOCH 385/2000
# Average loss: 0.6869
# EPOCH 386/2000
# Average loss: 0.6865
# EPOCH 387/2000
# Average loss: 0.6832
# EPOCH 388/2000
# Average loss: 0.6809
# EPOCH 389/2000
# Average loss: 0.6801
# EPOCH 390/2000
# Average loss: 0.6774
# EPOCH 391/2000
# Average loss: 0.6769
# EPOCH 392/2000
# Average loss: 0.6745
# EPOCH 393/2000
# Average loss: 0.6719
# EPOCH 394/2000
# Average loss: 0.6714
# EPOCH 395/2000
# Average loss: 0.6689
# EPOCH 396/2000
# Average loss: 0.6684
# EPOCH 397/2000
# Average loss: 0.6662
# EPOCH 398/2000
# Average loss: 0.6654
# EPOCH 399/2000
# Average loss: 0.6629
# EPOCH 400/2000
# Average loss: 0.6602
# EPOCH 401/2000
# Average loss: 0.6590
# EPOCH 402/2000
# Average loss: 0.6579
# EPOCH 403/2000
# Average loss: 0.6557
# EPOCH 404/2000
# Average loss: 0.6519
# EPOCH 405/2000
# Average loss: 0.6515
# EPOCH 406/2000
# Average loss: 0.6490
# EPOCH 407/2000
# Average loss: 0.6489
# EPOCH 408/2000
# Average loss: 0.6472
# EPOCH 409/2000
# Average loss: 0.6462
# EPOCH 410/2000
# Average loss: 0.6427
# EPOCH 411/2000
# Average loss: 0.6418
# EPOCH 412/2000
# Average loss: 0.6416
# EPOCH 413/2000
# Average loss: 0.6391
# EPOCH 414/2000
# Average loss: 0.6348
# EPOCH 415/2000
# Average loss: 0.6342
# EPOCH 416/2000
# Average loss: 0.6309
# EPOCH 417/2000
# Average loss: 0.6323
# EPOCH 418/2000
# Average loss: 0.6300
# EPOCH 419/2000
# Average loss: 0.6296
# EPOCH 420/2000
# Average loss: 0.6275
# EPOCH 421/2000
# Average loss: 0.6250
# EPOCH 422/2000
# Average loss: 0.6226
# EPOCH 423/2000
# Average loss: 0.6218
# EPOCH 424/2000
# Average loss: 0.6197
# EPOCH 425/2000
# Average loss: 0.6186
# EPOCH 426/2000
# Average loss: 0.6168
# EPOCH 427/2000
# Average loss: 0.6171
# EPOCH 428/2000
# Average loss: 0.6152
# EPOCH 429/2000
# Average loss: 0.6119
# EPOCH 430/2000
# Average loss: 0.6111
# EPOCH 431/2000
# Average loss: 0.6099
# EPOCH 432/2000
# Average loss: 0.6085
# EPOCH 433/2000
# Average loss: 0.6054
# EPOCH 434/2000
# Average loss: 0.6037
# EPOCH 435/2000
# Average loss: 0.6024
# EPOCH 436/2000
# Average loss: 0.6029
# EPOCH 437/2000
# Average loss: 0.6005
# EPOCH 438/2000
# Average loss: 0.5982
# EPOCH 439/2000
# Average loss: 0.5972
# EPOCH 440/2000
# Average loss: 0.5965
# EPOCH 441/2000
# Average loss: 0.5936
# EPOCH 442/2000
# Average loss: 0.5934
# EPOCH 443/2000
# Average loss: 0.5926
# EPOCH 444/2000
# Average loss: 0.5889
# EPOCH 445/2000
# Average loss: 0.5874
# EPOCH 446/2000
# Average loss: 0.5867
# EPOCH 447/2000
# Average loss: 0.5871
# EPOCH 448/2000
# Average loss: 0.5831
# EPOCH 449/2000
# Average loss: 0.5824
# EPOCH 450/2000
# Average loss: 0.5800
# EPOCH 451/2000
# Average loss: 0.5790
# EPOCH 452/2000
# Average loss: 0.5783
# EPOCH 453/2000
# Average loss: 0.5761
# EPOCH 454/2000
# Average loss: 0.5738
# EPOCH 455/2000
# Average loss: 0.5737
# EPOCH 456/2000
# Average loss: 0.5730
# EPOCH 457/2000
# Average loss: 0.5701
# EPOCH 458/2000
# Average loss: 0.5689
# EPOCH 459/2000
# Average loss: 0.5688
# EPOCH 460/2000
# Average loss: 0.5665
# EPOCH 461/2000
# Average loss: 0.5653
# EPOCH 462/2000
# Average loss: 0.5638
# EPOCH 463/2000
# Average loss: 0.5635
# EPOCH 464/2000
# Average loss: 0.5611
# EPOCH 465/2000
# Average loss: 0.5611
# EPOCH 466/2000
# Average loss: 0.5581
# EPOCH 467/2000
# Average loss: 0.5568
# EPOCH 468/2000
# Average loss: 0.5561
# EPOCH 469/2000
# Average loss: 0.5545
# EPOCH 470/2000
# Average loss: 0.5539
# EPOCH 471/2000
# Average loss: 0.5519
# EPOCH 472/2000
# Average loss: 0.5515
# EPOCH 473/2000
# Average loss: 0.5500
# EPOCH 474/2000
# Average loss: 0.5485
# EPOCH 475/2000
# Average loss: 0.5472
# EPOCH 476/2000
# Average loss: 0.5458
# EPOCH 477/2000
# Average loss: 0.5431
# EPOCH 478/2000
# Average loss: 0.5436
# EPOCH 479/2000
# Average loss: 0.5409
# EPOCH 480/2000
# Average loss: 0.5398
# EPOCH 481/2000
# Average loss: 0.5391
# EPOCH 482/2000
# Average loss: 0.5376
# EPOCH 483/2000
# Average loss: 0.5363
# EPOCH 484/2000
# Average loss: 0.5349
# EPOCH 485/2000
# Average loss: 0.5335
# EPOCH 486/2000
# Average loss: 0.5333
# EPOCH 487/2000
# Average loss: 0.5319
# EPOCH 488/2000
# Average loss: 0.5307
# EPOCH 489/2000
# Average loss: 0.5294
# EPOCH 490/2000
# Average loss: 0.5291
# EPOCH 491/2000
# Average loss: 0.5269
# EPOCH 492/2000
# Average loss: 0.5255
# EPOCH 493/2000
# Average loss: 0.5236
# EPOCH 494/2000
# Average loss: 0.5239
# EPOCH 495/2000
# Average loss: 0.5217
# EPOCH 496/2000
# Average loss: 0.5199
# EPOCH 497/2000
# Average loss: 0.5180
# EPOCH 498/2000
# Average loss: 0.5186
# EPOCH 499/2000
# Average loss: 0.5181
# EPOCH 500/2000
# Average loss: 0.5136
# EPOCH 501/2000
# Average loss: 0.5137
# EPOCH 502/2000
# Average loss: 0.5122
# EPOCH 503/2000
# Average loss: 0.5107
# EPOCH 504/2000
# Average loss: 0.5099
# EPOCH 505/2000
# Average loss: 0.5097
# EPOCH 506/2000
# Average loss: 0.5081
# EPOCH 507/2000
# Average loss: 0.5077
# EPOCH 508/2000
# Average loss: 0.5070
# EPOCH 509/2000
# Average loss: 0.5053
# EPOCH 510/2000
# Average loss: 0.5041
# EPOCH 511/2000
# Average loss: 0.5045
# EPOCH 512/2000
# Average loss: 0.5031
# EPOCH 513/2000
# Average loss: 0.5014
# EPOCH 514/2000
# Average loss: 0.5003
# EPOCH 515/2000
# Average loss: 0.4996
# EPOCH 516/2000
# Average loss: 0.4975
# EPOCH 517/2000
# Average loss: 0.4956
# EPOCH 518/2000
# Average loss: 0.4952
# EPOCH 519/2000
# Average loss: 0.4957
# EPOCH 520/2000
# Average loss: 0.4943
# EPOCH 521/2000
# Average loss: 0.4922
# EPOCH 522/2000
# Average loss: 0.4913
# EPOCH 523/2000
# Average loss: 0.4895
# EPOCH 524/2000
# Average loss: 0.4891
# EPOCH 525/2000
# Average loss: 0.4872
# EPOCH 526/2000
# Average loss: 0.4864
# EPOCH 527/2000
# Average loss: 0.4854
# EPOCH 528/2000
# Average loss: 0.4841
# EPOCH 529/2000
# Average loss: 0.4827
# EPOCH 530/2000
# Average loss: 0.4840
# EPOCH 531/2000
# Average loss: 0.4811
# EPOCH 532/2000
# Average loss: 0.4801
# EPOCH 533/2000
# Average loss: 0.4790
# EPOCH 534/2000
# Average loss: 0.4785
# EPOCH 535/2000
# Average loss: 0.4791
# EPOCH 536/2000
# Average loss: 0.4761
# EPOCH 537/2000
# Average loss: 0.4749
# EPOCH 538/2000
# Average loss: 0.4753
# EPOCH 539/2000
# Average loss: 0.4744
# EPOCH 540/2000
# Average loss: 0.4729
# EPOCH 541/2000
# Average loss: 0.4720
# EPOCH 542/2000
# Average loss: 0.4703
# EPOCH 543/2000
# Average loss: 0.4700
# EPOCH 544/2000
# Average loss: 0.4690
# EPOCH 545/2000
# Average loss: 0.4676
# EPOCH 546/2000
# Average loss: 0.4670
# EPOCH 547/2000
# Average loss: 0.4662
# EPOCH 548/2000
# Average loss: 0.4645
# EPOCH 549/2000
# Average loss: 0.4622
# EPOCH 550/2000
# Average loss: 0.4632
# EPOCH 551/2000
# Average loss: 0.4632
# EPOCH 552/2000
# Average loss: 0.4616
# EPOCH 553/2000
# Average loss: 0.4607
# EPOCH 554/2000
# Average loss: 0.4601
# EPOCH 555/2000
# Average loss: 0.4565
# EPOCH 556/2000
# Average loss: 0.4564
# EPOCH 557/2000
# Average loss: 0.4561
# EPOCH 558/2000
# Average loss: 0.4559
# EPOCH 559/2000
# Average loss: 0.4527
# EPOCH 560/2000
# Average loss: 0.4544
# EPOCH 561/2000
# Average loss: 0.4530
# EPOCH 562/2000
# Average loss: 0.4509
# EPOCH 563/2000
# Average loss: 0.4488
# EPOCH 564/2000
# Average loss: 0.4491
# EPOCH 565/2000
# Average loss: 0.4475
# EPOCH 566/2000
# Average loss: 0.4472
# EPOCH 567/2000
# Average loss: 0.4465
# EPOCH 568/2000
# Average loss: 0.4453
# EPOCH 569/2000
# Average loss: 0.4456
# EPOCH 570/2000
# Average loss: 0.4444
# EPOCH 571/2000
# Average loss: 0.4427
# EPOCH 572/2000
# Average loss: 0.4418
# EPOCH 573/2000
# Average loss: 0.4424
# EPOCH 574/2000
# Average loss: 0.4415
# EPOCH 575/2000
# Average loss: 0.4396
# EPOCH 576/2000
# Average loss: 0.4393
# EPOCH 577/2000
# Average loss: 0.4389
# EPOCH 578/2000
# Average loss: 0.4359
# EPOCH 579/2000
# Average loss: 0.4359
# EPOCH 580/2000
# Average loss: 0.4354
# EPOCH 581/2000
# Average loss: 0.4337
# EPOCH 582/2000
# Average loss: 0.4335
# EPOCH 583/2000
# Average loss: 0.4319
# EPOCH 584/2000
# Average loss: 0.4331
# EPOCH 585/2000
# Average loss: 0.4315
# EPOCH 586/2000
# Average loss: 0.4304
# EPOCH 587/2000
# Average loss: 0.4296
# EPOCH 588/2000
# Average loss: 0.4281
# EPOCH 589/2000
# Average loss: 0.4283
# EPOCH 590/2000
# Average loss: 0.4266
# EPOCH 591/2000
# Average loss: 0.4251
# EPOCH 592/2000
# Average loss: 0.4249
# EPOCH 593/2000
# Average loss: 0.4251
# EPOCH 594/2000
# Average loss: 0.4250
# EPOCH 595/2000
# Average loss: 0.4238
# EPOCH 596/2000
# Average loss: 0.4224
# EPOCH 597/2000
# Average loss: 0.4220
# EPOCH 598/2000
# Average loss: 0.4196
# EPOCH 599/2000
# Average loss: 0.4187
# EPOCH 600/2000
# Average loss: 0.4173
# EPOCH 601/2000
# Average loss: 0.4160
# EPOCH 602/2000
# Average loss: 0.4158
# EPOCH 603/2000
# Average loss: 0.4159
# EPOCH 604/2000
# Average loss: 0.4166
# EPOCH 605/2000
# Average loss: 0.4157
# EPOCH 606/2000
# Average loss: 0.4141
# EPOCH 607/2000
# Average loss: 0.4128
# EPOCH 608/2000
# Average loss: 0.4121
# EPOCH 609/2000
# Average loss: 0.4118
# EPOCH 610/2000
# Average loss: 0.4105
# EPOCH 611/2000
# Average loss: 0.4111
# EPOCH 612/2000
# Average loss: 0.4095
# EPOCH 613/2000
# Average loss: 0.4083
# EPOCH 614/2000
# Average loss: 0.4090
# EPOCH 615/2000
# Average loss: 0.4068
# EPOCH 616/2000
# Average loss: 0.4057
# EPOCH 617/2000
# Average loss: 0.4055
# EPOCH 618/2000
# Average loss: 0.4049
# EPOCH 619/2000
# Average loss: 0.4043
# EPOCH 620/2000
# Average loss: 0.4037
# EPOCH 621/2000
# Average loss: 0.4037
# EPOCH 622/2000
# Average loss: 0.4017
# EPOCH 623/2000
# Average loss: 0.4013
# EPOCH 624/2000
# Average loss: 0.4016
# EPOCH 625/2000
# Average loss: 0.3990
# EPOCH 626/2000
# Average loss: 0.3987
# EPOCH 627/2000
# Average loss: 0.3976
# EPOCH 628/2000
# Average loss: 0.3955
# EPOCH 629/2000
# Average loss: 0.3966
# EPOCH 630/2000
# Average loss: 0.3951
# EPOCH 631/2000
# Average loss: 0.3953
# EPOCH 632/2000
# Average loss: 0.3941
# EPOCH 633/2000
# Average loss: 0.3934
# EPOCH 634/2000
# Average loss: 0.3929
# EPOCH 635/2000
# Average loss: 0.3920
# EPOCH 636/2000
# Average loss: 0.3912
# EPOCH 637/2000
# Average loss: 0.3908
# EPOCH 638/2000
# Average loss: 0.3909
# EPOCH 639/2000
# Average loss: 0.3895
# EPOCH 640/2000
# Average loss: 0.3884
# EPOCH 641/2000
# Average loss: 0.3876
# EPOCH 642/2000
# Average loss: 0.3887
# EPOCH 643/2000
# Average loss: 0.3880
# EPOCH 644/2000
# Average loss: 0.3862
# EPOCH 645/2000
# Average loss: 0.3858
# EPOCH 646/2000
# Average loss: 0.3856
# EPOCH 647/2000
# Average loss: 0.3856
# EPOCH 648/2000
# Average loss: 0.3843
# EPOCH 649/2000
# Average loss: 0.3830
# EPOCH 650/2000
# Average loss: 0.3816
# EPOCH 651/2000
# Average loss: 0.3822
# EPOCH 652/2000
# Average loss: 0.3827
# EPOCH 653/2000
# Average loss: 0.3821
# EPOCH 654/2000
# Average loss: 0.3800
# EPOCH 655/2000
# Average loss: 0.3791
# EPOCH 656/2000
# Average loss: 0.3784
# EPOCH 657/2000
# Average loss: 0.3775
# EPOCH 658/2000
# Average loss: 0.3784
# EPOCH 659/2000
# Average loss: 0.3781
# EPOCH 660/2000
# Average loss: 0.3764
# EPOCH 661/2000
# Average loss: 0.3759
# EPOCH 662/2000
# Average loss: 0.3760
# EPOCH 663/2000
# Average loss: 0.3747
# EPOCH 664/2000
# Average loss: 0.3742
# EPOCH 665/2000
# Average loss: 0.3727
# EPOCH 666/2000
# Average loss: 0.3713
# EPOCH 667/2000
# Average loss: 0.3698
# EPOCH 668/2000
# Average loss: 0.3720
# EPOCH 669/2000
# Average loss: 0.3704
# EPOCH 670/2000
# Average loss: 0.3712
# EPOCH 671/2000
# Average loss: 0.3682
# EPOCH 672/2000
# Average loss: 0.3693
# EPOCH 673/2000
# Average loss: 0.3685
# EPOCH 674/2000
# Average loss: 0.3677
# EPOCH 675/2000
# Average loss: 0.3665
# EPOCH 676/2000
# Average loss: 0.3674
# EPOCH 677/2000
# Average loss: 0.3668
# EPOCH 678/2000
# Average loss: 0.3660
# EPOCH 679/2000
# Average loss: 0.3649
# EPOCH 680/2000
# Average loss: 0.3632
# EPOCH 681/2000
# Average loss: 0.3634
# EPOCH 682/2000
# Average loss: 0.3618
# EPOCH 683/2000
# Average loss: 0.3606
# EPOCH 684/2000
# Average loss: 0.3613
# EPOCH 685/2000
# Average loss: 0.3605
# EPOCH 686/2000
# Average loss: 0.3601
# EPOCH 687/2000
# Average loss: 0.3602
# EPOCH 688/2000
# Average loss: 0.3597
# EPOCH 689/2000
# Average loss: 0.3575
# EPOCH 690/2000
# Average loss: 0.3568
# EPOCH 691/2000
# Average loss: 0.3583
# EPOCH 692/2000
# Average loss: 0.3561
# EPOCH 693/2000
# Average loss: 0.3561
# EPOCH 694/2000
# Average loss: 0.3556
# EPOCH 695/2000
# Average loss: 0.3540
# EPOCH 696/2000
# Average loss: 0.3540
# EPOCH 697/2000
# Average loss: 0.3534
# EPOCH 698/2000
# Average loss: 0.3519
# EPOCH 699/2000
# Average loss: 0.3538
# EPOCH 700/2000
# Average loss: 0.3520
# EPOCH 701/2000
# Average loss: 0.3510
# EPOCH 702/2000
# Average loss: 0.3511
# EPOCH 703/2000
# Average loss: 0.3505
# EPOCH 704/2000
# Average loss: 0.3501
# EPOCH 705/2000
# Average loss: 0.3494
# EPOCH 706/2000
# Average loss: 0.3499
# EPOCH 707/2000
# Average loss: 0.3485
# EPOCH 708/2000
# Average loss: 0.3475
# EPOCH 709/2000
# Average loss: 0.3484
# EPOCH 710/2000
# Average loss: 0.3463
# EPOCH 711/2000
# Average loss: 0.3465
# EPOCH 712/2000
# Average loss: 0.3455
# EPOCH 713/2000
# Average loss: 0.3439
# EPOCH 714/2000
# Average loss: 0.3442
# EPOCH 715/2000
# Average loss: 0.3438
# EPOCH 716/2000
# Average loss: 0.3429
# EPOCH 717/2000
# Average loss: 0.3434
# EPOCH 718/2000
# Average loss: 0.3427
# EPOCH 719/2000
# Average loss: 0.3420
# EPOCH 720/2000
# Average loss: 0.3420
# EPOCH 721/2000
# Average loss: 0.3415
# EPOCH 722/2000
# Average loss: 0.3418
# EPOCH 723/2000
# Average loss: 0.3384
# EPOCH 724/2000
# Average loss: 0.3394
# EPOCH 725/2000
# Average loss: 0.3388
# EPOCH 726/2000
# Average loss: 0.3376
# EPOCH 727/2000
# Average loss: 0.3377
# EPOCH 728/2000
# Average loss: 0.3383
# EPOCH 729/2000
# Average loss: 0.3366
# EPOCH 730/2000
# Average loss: 0.3361
# EPOCH 731/2000
# Average loss: 0.3362
# EPOCH 732/2000
# Average loss: 0.3370
# EPOCH 733/2000
# Average loss: 0.3351
# EPOCH 734/2000
# Average loss: 0.3353
# EPOCH 735/2000
# Average loss: 0.3342
# EPOCH 736/2000
# Average loss: 0.3335
# EPOCH 737/2000
# Average loss: 0.3341
# EPOCH 738/2000
# Average loss: 0.3333
# EPOCH 739/2000
# Average loss: 0.3321
# EPOCH 740/2000
# Average loss: 0.3309
# EPOCH 741/2000
# Average loss: 0.3319
# EPOCH 742/2000
# Average loss: 0.3315
# EPOCH 743/2000
# Average loss: 0.3295
# EPOCH 744/2000
# Average loss: 0.3312
# EPOCH 745/2000
# Average loss: 0.3282
# EPOCH 746/2000
# Average loss: 0.3274
# EPOCH 747/2000
# Average loss: 0.3257
# EPOCH 748/2000
# Average loss: 0.3281
# EPOCH 749/2000
# Average loss: 0.3269
# EPOCH 750/2000
# Average loss: 0.3271
# EPOCH 751/2000
# Average loss: 0.3261
# EPOCH 752/2000
# Average loss: 0.3247
# EPOCH 753/2000
# Average loss: 0.3258
# EPOCH 754/2000
# Average loss: 0.3245
# EPOCH 755/2000
# Average loss: 0.3247
# EPOCH 756/2000
# Average loss: 0.3239
# EPOCH 757/2000
# Average loss: 0.3242
# EPOCH 758/2000
# Average loss: 0.3238
# EPOCH 759/2000
# Average loss: 0.3232
# EPOCH 760/2000
# Average loss: 0.3211
# EPOCH 761/2000
# Average loss: 0.3215
# EPOCH 762/2000
# Average loss: 0.3212
# EPOCH 763/2000
# Average loss: 0.3204
# EPOCH 764/2000
# Average loss: 0.3200
# EPOCH 765/2000
# Average loss: 0.3206
# EPOCH 766/2000
# Average loss: 0.3192
# EPOCH 767/2000
# Average loss: 0.3184
# EPOCH 768/2000
# Average loss: 0.3185
# EPOCH 769/2000
# Average loss: 0.3188
# EPOCH 770/2000
# Average loss: 0.3176
# EPOCH 771/2000
# Average loss: 0.3170
# EPOCH 772/2000
# Average loss: 0.3168
# EPOCH 773/2000
# Average loss: 0.3160
# EPOCH 774/2000
# Average loss: 0.3165
# EPOCH 775/2000
# Average loss: 0.3155
# EPOCH 776/2000
# Average loss: 0.3157
# EPOCH 777/2000
# Average loss: 0.3165
# EPOCH 778/2000
# Average loss: 0.3135
# EPOCH 779/2000
# Average loss: 0.3135
# EPOCH 780/2000
# Average loss: 0.3134
# EPOCH 781/2000
# Average loss: 0.3126
# EPOCH 782/2000
# Average loss: 0.3127
# EPOCH 783/2000
# Average loss: 0.3129
# EPOCH 784/2000
# Average loss: 0.3120
# EPOCH 785/2000
# Average loss: 0.3107
# EPOCH 786/2000
# Average loss: 0.3111
# EPOCH 787/2000
# Average loss: 0.3110
# EPOCH 788/2000
# Average loss: 0.3102
# EPOCH 789/2000
# Average loss: 0.3100
# EPOCH 790/2000
# Average loss: 0.3098
# EPOCH 791/2000
# Average loss: 0.3081
# EPOCH 792/2000
# Average loss: 0.3087
# EPOCH 793/2000
# Average loss: 0.3082
# EPOCH 794/2000
# Average loss: 0.3079
# EPOCH 795/2000
# Average loss: 0.3064
# EPOCH 796/2000
# Average loss: 0.3071
# EPOCH 797/2000
# Average loss: 0.3088
# EPOCH 798/2000
# Average loss: 0.3068
# EPOCH 799/2000
# Average loss: 0.3056
# EPOCH 800/2000
# Average loss: 0.3050
# EPOCH 801/2000
# Average loss: 0.3041
# EPOCH 802/2000
# Average loss: 0.3030
# EPOCH 803/2000
# Average loss: 0.3040
# EPOCH 804/2000
# Average loss: 0.3037
# EPOCH 805/2000
# Average loss: 0.3025
# EPOCH 806/2000
# Average loss: 0.3024
# EPOCH 807/2000
# Average loss: 0.3025
# EPOCH 808/2000
# Average loss: 0.3021
# EPOCH 809/2000
# Average loss: 0.3010
# EPOCH 810/2000
# Average loss: 0.3004
# EPOCH 811/2000
# Average loss: 0.3006
# EPOCH 812/2000
# Average loss: 0.3003
# EPOCH 813/2000
# Average loss: 0.3003
# EPOCH 814/2000
# Average loss: 0.3010
# EPOCH 815/2000
# Average loss: 0.2986
# EPOCH 816/2000
# Average loss: 0.2974
# EPOCH 817/2000
# Average loss: 0.2970
# EPOCH 818/2000
# Average loss: 0.2988
# EPOCH 819/2000
# Average loss: 0.2972
# EPOCH 820/2000
# Average loss: 0.2974
# EPOCH 821/2000
# Average loss: 0.2980
# EPOCH 822/2000
# Average loss: 0.2963
# EPOCH 823/2000
# Average loss: 0.2967
# EPOCH 824/2000
# Average loss: 0.2962
# EPOCH 825/2000
# Average loss: 0.2960
# EPOCH 826/2000
# Average loss: 0.2939
# EPOCH 827/2000
# Average loss: 0.2940
# EPOCH 828/2000
# Average loss: 0.2953
# EPOCH 829/2000
# Average loss: 0.2939
# EPOCH 830/2000
# Average loss: 0.2936
# EPOCH 831/2000
# Average loss: 0.2938
# EPOCH 832/2000
# Average loss: 0.2946
# EPOCH 833/2000
# Average loss: 0.2940
# EPOCH 834/2000
# Average loss: 0.2922
# EPOCH 835/2000
# Average loss: 0.2927
# EPOCH 836/2000
# Average loss: 0.2916
# EPOCH 837/2000
# Average loss: 0.2913
# EPOCH 838/2000
# Average loss: 0.2905
# EPOCH 839/2000
# Average loss: 0.2910
# EPOCH 840/2000
# Average loss: 0.2909
# EPOCH 841/2000
# Average loss: 0.2899
# EPOCH 842/2000
# Average loss: 0.2896
# EPOCH 843/2000
# Average loss: 0.2897
# EPOCH 844/2000
# Average loss: 0.2887
# EPOCH 845/2000
# Average loss: 0.2897
# EPOCH 846/2000
# Average loss: 0.2877
# EPOCH 847/2000
# Average loss: 0.2870
# EPOCH 848/2000
# Average loss: 0.2878
# EPOCH 849/2000
# Average loss: 0.2871
# EPOCH 850/2000
# Average loss: 0.2888
# EPOCH 851/2000
# Average loss: 0.2864
# EPOCH 852/2000
# Average loss: 0.2847
# EPOCH 853/2000
# Average loss: 0.2850
# EPOCH 854/2000
# Average loss: 0.2869
# EPOCH 855/2000
# Average loss: 0.2856
# EPOCH 856/2000
# Average loss: 0.2843
# EPOCH 857/2000
# Average loss: 0.2845
# EPOCH 858/2000
# Average loss: 0.2840
# EPOCH 859/2000
# Average loss: 0.2838
# EPOCH 860/2000
# Average loss: 0.2846
# EPOCH 861/2000
# Average loss: 0.2843
# EPOCH 862/2000
# Average loss: 0.2826
# EPOCH 863/2000
# Average loss: 0.2842
# EPOCH 864/2000
# Average loss: 0.2827
# EPOCH 865/2000
# Average loss: 0.2825
# EPOCH 866/2000
# Average loss: 0.2818
# EPOCH 867/2000
# Average loss: 0.2830
# EPOCH 868/2000
# Average loss: 0.2815
# EPOCH 869/2000
# Average loss: 0.2806
# EPOCH 870/2000
# Average loss: 0.2811
# EPOCH 871/2000
# Average loss: 0.2792
# EPOCH 872/2000
# Average loss: 0.2793
# EPOCH 873/2000
# Average loss: 0.2802
# EPOCH 874/2000
# Average loss: 0.2783
# EPOCH 875/2000
# Average loss: 0.2784
# EPOCH 876/2000
# Average loss: 0.2782
# EPOCH 877/2000
# Average loss: 0.2791
# EPOCH 878/2000
# Average loss: 0.2778
# EPOCH 879/2000
# Average loss: 0.2768
# EPOCH 880/2000
# Average loss: 0.2781
# EPOCH 881/2000
# Average loss: 0.2767
# EPOCH 882/2000
# Average loss: 0.2773
# EPOCH 883/2000
# Average loss: 0.2759
# EPOCH 884/2000
# Average loss: 0.2757
# EPOCH 885/2000
# Average loss: 0.2736
# EPOCH 886/2000
# Average loss: 0.2755
# EPOCH 887/2000
# Average loss: 0.2751
# EPOCH 888/2000
# Average loss: 0.2759
# EPOCH 889/2000
# Average loss: 0.2741
# EPOCH 890/2000
# Average loss: 0.2738
# EPOCH 891/2000
# Average loss: 0.2718
# EPOCH 892/2000
# Average loss: 0.2742
# EPOCH 893/2000
# Average loss: 0.2729
# EPOCH 894/2000
# Average loss: 0.2727
# EPOCH 895/2000
# Average loss: 0.2726
# EPOCH 896/2000
# Average loss: 0.2713
# EPOCH 897/2000
# Average loss: 0.2713
# EPOCH 898/2000
# Average loss: 0.2701
# EPOCH 899/2000
# Average loss: 0.2713
# EPOCH 900/2000
# Average loss: 0.2697
# EPOCH 901/2000
# Average loss: 0.2708
# EPOCH 902/2000
# Average loss: 0.2709
# EPOCH 903/2000
# Average loss: 0.2699
# EPOCH 904/2000
# Average loss: 0.2701
# EPOCH 905/2000
# Average loss: 0.2690
# EPOCH 906/2000
# Average loss: 0.2682
# EPOCH 907/2000
# Average loss: 0.2672
# EPOCH 908/2000
# Average loss: 0.2685
# EPOCH 909/2000
# Average loss: 0.2679
# EPOCH 910/2000
# Average loss: 0.2680
# EPOCH 911/2000
# Average loss: 0.2679
# EPOCH 912/2000
# Average loss: 0.2672
# EPOCH 913/2000
# Average loss: 0.2661
# EPOCH 914/2000
# Average loss: 0.2664
# EPOCH 915/2000
# Average loss: 0.2663
# EPOCH 916/2000
# Average loss: 0.2673
# EPOCH 917/2000
# Average loss: 0.2674
# EPOCH 918/2000
# Average loss: 0.2664
# EPOCH 919/2000
# Average loss: 0.2640
# EPOCH 920/2000
# Average loss: 0.2655
# EPOCH 921/2000
# Average loss: 0.2634
# EPOCH 922/2000
# Average loss: 0.2645
# EPOCH 923/2000
# Average loss: 0.2642
# EPOCH 924/2000
# Average loss: 0.2636
# EPOCH 925/2000
# Average loss: 0.2627
# EPOCH 926/2000
# Average loss: 0.2631
# EPOCH 927/2000
# Average loss: 0.2640
# EPOCH 928/2000
# Average loss: 0.2614
# EPOCH 929/2000
# Average loss: 0.2617
# EPOCH 930/2000
# Average loss: 0.2625
# EPOCH 931/2000
# Average loss: 0.2622
# EPOCH 932/2000
# Average loss: 0.2620
# EPOCH 933/2000
# Average loss: 0.2615
# EPOCH 934/2000
# Average loss: 0.2618
# EPOCH 935/2000
# Average loss: 0.2605
# EPOCH 936/2000
# Average loss: 0.2604
# EPOCH 937/2000
# Average loss: 0.2614
# EPOCH 938/2000
# Average loss: 0.2613
# EPOCH 939/2000
# Average loss: 0.2605
# EPOCH 940/2000
# Average loss: 0.2602
# EPOCH 941/2000
# Average loss: 0.2588
# EPOCH 942/2000
# Average loss: 0.2606
# EPOCH 943/2000
# Average loss: 0.2579
# EPOCH 944/2000
# Average loss: 0.2587
# EPOCH 945/2000
# Average loss: 0.2590
# EPOCH 946/2000
# Average loss: 0.2575
# EPOCH 947/2000
# Average loss: 0.2577
# EPOCH 948/2000
# Average loss: 0.2588
# EPOCH 949/2000
# Average loss: 0.2573
# EPOCH 950/2000
# Average loss: 0.2562
# EPOCH 951/2000
# Average loss: 0.2566
# EPOCH 952/2000
# Average loss: 0.2563
# EPOCH 953/2000
# Average loss: 0.2571
# EPOCH 954/2000
# Average loss: 0.2561
# EPOCH 955/2000
# Average loss: 0.2562
# EPOCH 956/2000
# Average loss: 0.2559
# EPOCH 957/2000
# Average loss: 0.2543
# EPOCH 958/2000
# Average loss: 0.2544
# EPOCH 959/2000
# Average loss: 0.2558
# EPOCH 960/2000
# Average loss: 0.2543
# EPOCH 961/2000
# Average loss: 0.2543
# EPOCH 962/2000
# Average loss: 0.2545
# EPOCH 963/2000
# Average loss: 0.2533
# EPOCH 964/2000
# Average loss: 0.2535
# EPOCH 965/2000
# Average loss: 0.2518
# EPOCH 966/2000
# Average loss: 0.2533
# EPOCH 967/2000
# Average loss: 0.2533
# EPOCH 968/2000
# Average loss: 0.2533
# EPOCH 969/2000
# Average loss: 0.2515
# EPOCH 970/2000
# Average loss: 0.2521
# EPOCH 971/2000
# Average loss: 0.2516
# EPOCH 972/2000
# Average loss: 0.2515
# EPOCH 973/2000
# Average loss: 0.2518
# EPOCH 974/2000
# Average loss: 0.2507
# EPOCH 975/2000
# Average loss: 0.2510
# EPOCH 976/2000
# Average loss: 0.2495
# EPOCH 977/2000
# Average loss: 0.2501
# EPOCH 978/2000
# Average loss: 0.2493
# EPOCH 979/2000
# Average loss: 0.2494
# EPOCH 980/2000
# Average loss: 0.2489
# EPOCH 981/2000
# Average loss: 0.2489
# EPOCH 982/2000
# Average loss: 0.2483
# EPOCH 983/2000
# Average loss: 0.2482
# EPOCH 984/2000
# Average loss: 0.2477
# EPOCH 985/2000
# Average loss: 0.2473
# EPOCH 986/2000
# Average loss: 0.2472
# EPOCH 987/2000
# Average loss: 0.2473
# EPOCH 988/2000
# Average loss: 0.2471
# EPOCH 989/2000
# Average loss: 0.2484
# EPOCH 990/2000
# Average loss: 0.2472
# EPOCH 991/2000
# Average loss: 0.2473
# EPOCH 992/2000
# Average loss: 0.2471
# EPOCH 993/2000
# Average loss: 0.2464
# EPOCH 994/2000
# Average loss: 0.2468
# EPOCH 995/2000
# Average loss: 0.2467
# EPOCH 996/2000
# Average loss: 0.2459
# EPOCH 997/2000
# Average loss: 0.2449
# EPOCH 998/2000
# Average loss: 0.2448
# EPOCH 999/2000
# Average loss: 0.2438
# EPOCH 1000/2000
# Average loss: 0.2444
# EPOCH 1001/2000
# Average loss: 0.2441
# EPOCH 1002/2000
# Average loss: 0.2449
# EPOCH 1003/2000
# Average loss: 0.2449
# EPOCH 1004/2000
# Average loss: 0.2438
# EPOCH 1005/2000
# Average loss: 0.2441
# EPOCH 1006/2000
# Average loss: 0.2431
# EPOCH 1007/2000
# Average loss: 0.2428
# EPOCH 1008/2000
# Average loss: 0.2430
# EPOCH 1009/2000
# Average loss: 0.2427
# EPOCH 1010/2000
# Average loss: 0.2433
# EPOCH 1011/2000
# Average loss: 0.2439
# EPOCH 1012/2000
# Average loss: 0.2428
# EPOCH 1013/2000
# Average loss: 0.2420
# EPOCH 1014/2000
# Average loss: 0.2408
# EPOCH 1015/2000
# Average loss: 0.2427
# EPOCH 1016/2000
# Average loss: 0.2418
# EPOCH 1017/2000
# Average loss: 0.2418
# EPOCH 1018/2000
# Average loss: 0.2400
# EPOCH 1019/2000
# Average loss: 0.2401
# EPOCH 1020/2000
# Average loss: 0.2396
# EPOCH 1021/2000
# Average loss: 0.2404
# EPOCH 1022/2000
# Average loss: 0.2387
# EPOCH 1023/2000
# Average loss: 0.2397
# EPOCH 1024/2000
# Average loss: 0.2402
# EPOCH 1025/2000
# Average loss: 0.2412
# EPOCH 1026/2000
# Average loss: 0.2397
# EPOCH 1027/2000
# Average loss: 0.2387
# EPOCH 1028/2000
# Average loss: 0.2382
# EPOCH 1029/2000
# Average loss: 0.2386
# EPOCH 1030/2000
# Average loss: 0.2376
# EPOCH 1031/2000
# Average loss: 0.2384
# EPOCH 1032/2000
# Average loss: 0.2386
# EPOCH 1033/2000
# Average loss: 0.2367
# EPOCH 1034/2000
# Average loss: 0.2380
# EPOCH 1035/2000
# Average loss: 0.2352
# EPOCH 1036/2000
# Average loss: 0.2371
# EPOCH 1037/2000
# Average loss: 0.2378
# EPOCH 1038/2000
# Average loss: 0.2373
# EPOCH 1039/2000
# Average loss: 0.2370
# EPOCH 1040/2000
# Average loss: 0.2364
# EPOCH 1288/2000
# Average loss: 0.1960
# EPOCH 1289/2000
# Average loss: 0.1971
# EPOCH 1290/2000
# Average loss: 0.1946
# EPOCH 1291/2000
# Average loss: 0.1957
# EPOCH 1292/2000
# Average loss: 0.1959
# EPOCH 1293/2000
# Average loss: 0.1955
# EPOCH 1294/2000
# Average loss: 0.1948
# EPOCH 1295/2000
# Average loss: 0.1963
# EPOCH 1296/2000
# Average loss: 0.1948
# EPOCH 1297/2000
# Average loss: 0.1955
# EPOCH 1298/2000
# Average loss: 0.1958
# EPOCH 1299/2000
# Average loss: 0.1942
# EPOCH 1300/2000
# Average loss: 0.1936
# EPOCH 1301/2000
# Average loss: 0.1961
# EPOCH 1302/2000
# Average loss: 0.1944
# EPOCH 1303/2000
# Average loss: 0.1944
# EPOCH 1304/2000
# Average loss: 0.1937
# EPOCH 1305/2000
# Average loss: 0.1936
# EPOCH 1306/2000
# Average loss: 0.1928
# EPOCH 1307/2000
# Average loss: 0.1939
# EPOCH 1308/2000
# Average loss: 0.1948
# EPOCH 1309/2000
# Average loss: 0.1931
# EPOCH 1310/2000
# Average loss: 0.1935
# EPOCH 1311/2000
# Average loss: 0.1936
# EPOCH 1312/2000
# Average loss: 0.1928
# EPOCH 1313/2000
# Average loss: 0.1938
# EPOCH 1314/2000
# Average loss: 0.1935
# EPOCH 1315/2000
# Average loss: 0.1929
# EPOCH 1316/2000
# Average loss: 0.1930
# EPOCH 1317/2000
# Average loss: 0.1925
# EPOCH 1318/2000
# Average loss: 0.1930
# EPOCH 1319/2000
# Average loss: 0.1925
# EPOCH 1320/2000
# Average loss: 0.1932
# EPOCH 1321/2000
# Average loss: 0.1934
# EPOCH 1322/2000
# Average loss: 0.1919
# EPOCH 1323/2000
# Average loss: 0.1913
# EPOCH 1324/2000
# Average loss: 0.1915
# EPOCH 1325/2000
# Average loss: 0.1910
# EPOCH 1326/2000
# Average loss: 0.1912
# ...
# EPOCH 1569/2000
# Average loss: 0.1689
# EPOCH 1570/2000
# Average loss: 0.1682
# EPOCH 1571/2000
# Average loss: 0.1684
# EPOCH 1572/2000
# Average loss: 0.1680
# EPOCH 1573/2000
# Average loss: 0.1693
# EPOCH 1574/2000
# Average loss: 0.1677
# EPOCH 1575/2000
# Average loss: 0.1686
# EPOCH 1576/2000
# Average loss: 0.1677
# EPOCH 1577/2000
# Average loss: 0.1680
# EPOCH 1578/2000
# Average loss: 0.1677
# EPOCH 1579/2000
# Average loss: 0.1682
# EPOCH 1580/2000
# Average loss: 0.1673
# EPOCH 1581/2000
# Average loss: 0.1693
# EPOCH 1582/2000
# Average loss: 0.1682
# EPOCH 1583/2000
# Average loss: 0.1682
# EPOCH 1584/2000
# Average loss: 0.1682
# EPOCH 1585/2000
# Average loss: 0.1672
# EPOCH 1586/2000
# Average loss: 0.1677
# EPOCH 1587/2000
# Average loss: 0.1672
# EPOCH 1588/2000
# Average loss: 0.1666
# EPOCH 1589/2000
# Average loss: 0.1672
# EPOCH 1590/2000
# Average loss: 0.1687
# EPOCH 1591/2000
# Average loss: 0.1677
# EPOCH 1592/2000
# Average loss: 0.1671
# EPOCH 1593/2000
# Average loss: 0.1668
# EPOCH 1594/2000
# Average loss: 0.1673
# EPOCH 1595/2000
# Average loss: 0.1672
# EPOCH 1596/2000
# Average loss: 0.1668
# EPOCH 1597/2000
# Average loss: 0.1661
# EPOCH 1598/2000
# Average loss: 0.1674
# EPOCH 1599/2000
# Average loss: 0.1661
# EPOCH 1600/2000
# Average loss: 0.1656
# EPOCH 1601/2000
# Average loss: 0.1668
# EPOCH 1602/2000
# Average loss: 0.1658
# EPOCH 1603/2000
# Average loss: 0.1666
# EPOCH 1604/2000
# Average loss: 0.1674
# EPOCH 1605/2000
# Average loss: 0.1668
# EPOCH 1606/2000
# Average loss: 0.1667
# EPOCH 1607/2000
# Average loss: 0.1657
# EPOCH 1608/2000
# Average loss: 0.1655
# EPOCH 1609/2000
# Average loss: 0.1658
# EPOCH 1610/2000
# Average loss: 0.1657
# EPOCH 1611/2000
# Average loss: 0.1668
# EPOCH 1612/2000
# Average loss: 0.1655
# EPOCH 1613/2000
# Average loss: 0.1665
# EPOCH 1614/2000
# Average loss: 0.1666
# EPOCH 1615/2000
# Average loss: 0.1651
# EPOCH 1616/2000
# Average loss: 0.1660
# EPOCH 1617/2000
# Average loss: 0.1654
# EPOCH 1618/2000
# Average loss: 0.1651
# EPOCH 1619/2000
# Average loss: 0.1658
# EPOCH 1620/2000
# Average loss: 0.1656
# EPOCH 1621/2000
# Average loss: 0.1648
# EPOCH 1622/2000
# Average loss: 0.1656
# EPOCH 1623/2000
# Average loss: 0.1639
# EPOCH 1624/2000
# Average loss: 0.1652
# EPOCH 1625/2000
# Average loss: 0.1648
# EPOCH 1626/2000
# Average loss: 0.1646
# EPOCH 1627/2000
# Average loss: 0.1650
# EPOCH 1628/2000
# Average loss: 0.1639
# EPOCH 1629/2000
# Average loss: 0.1657
# EPOCH 1630/2000
# Average loss: 0.1658
# EPOCH 1631/2000
# Average loss: 0.1624
# EPOCH 1632/2000
# Average loss: 0.1637
# EPOCH 1633/2000
# Average loss: 0.1643
# EPOCH 1634/2000
# Average loss: 0.1656
# EPOCH 1635/2000
# Average loss: 0.1645
# EPOCH 1636/2000
# Average loss: 0.1637
# EPOCH 1637/2000
# Average loss: 0.1643
# EPOCH 1638/2000
# Average loss: 0.1633
# EPOCH 1639/2000
# Average loss: 0.1640
# EPOCH 1640/2000
# Average loss: 0.1630
# EPOCH 1641/2000
# Average loss: 0.1637
# EPOCH 1642/2000
# Average loss: 0.1637
# EPOCH 1643/2000
# Average loss: 0.1635
# EPOCH 1644/2000
# Average loss: 0.1639
# EPOCH 1645/2000
# Average loss: 0.1631
# EPOCH 1646/2000
# Average loss: 0.1627
# EPOCH 1647/2000
# Average loss: 0.1639
# EPOCH 1648/2000
# Average loss: 0.1627
# EPOCH 1649/2000
# Average loss: 0.1616
# EPOCH 1650/2000
# Average loss: 0.1625
# EPOCH 1651/2000
# Average loss: 0.1621
# EPOCH 1652/2000
# Average loss: 0.1636
# EPOCH 1900/2000
# Average loss: 0.1477
# EPOCH 1901/2000
# Average loss: 0.1471
# EPOCH 1902/2000
# Average loss: 0.1485
# EPOCH 1903/2000
# Average loss: 0.1472
# EPOCH 1904/2000
# Average loss: 0.1470
# EPOCH 1905/2000
# Average loss: 0.1472
# EPOCH 1906/2000
# Average loss: 0.1477
# EPOCH 1907/2000
# Average loss: 0.1467
# EPOCH 1908/2000
# Average loss: 0.1473
# EPOCH 1909/2000
# Average loss: 0.1472
# EPOCH 1910/2000
# Average loss: 0.1478
# EPOCH 1911/2000
# Average loss: 0.1460
# EPOCH 1912/2000
# Average loss: 0.1482
# EPOCH 1913/2000
# Average loss: 0.1480
# EPOCH 1914/2000
# Average loss: 0.1473
# EPOCH 1915/2000
# Average loss: 0.1475
# EPOCH 1916/2000
# Average loss: 0.1474
# EPOCH 1917/2000
# Average loss: 0.1473
# EPOCH 1918/2000
# Average loss: 0.1479
# EPOCH 1919/2000
# Average loss: 0.1475
# EPOCH 1920/2000
# Average loss: 0.1463
# EPOCH 1921/2000
# Average loss: 0.1467
# EPOCH 1922/2000
# Average loss: 0.1466
# EPOCH 1923/2000
# Average loss: 0.1469
# EPOCH 1924/2000
# Average loss: 0.1470
# EPOCH 1925/2000
# Average loss: 0.1473
# EPOCH 1926/2000
# Average loss: 0.1469
# EPOCH 1927/2000
# Average loss: 0.1462
# EPOCH 1928/2000
# Average loss: 0.1464
# EPOCH 1929/2000
# Average loss: 0.1458
# EPOCH 1930/2000
# Average loss: 0.1463
# EPOCH 1931/2000
# Average loss: 0.1466
# EPOCH 1932/2000
# Average loss: 0.1460
# EPOCH 1933/2000
# Average loss: 0.1463
# EPOCH 1934/2000
# Average loss: 0.1465
# EPOCH 1935/2000
# Average loss: 0.1459
# EPOCH 1936/2000
# Average loss: 0.1453
# EPOCH 1937/2000
# Average loss: 0.1460
# EPOCH 1938/2000
# Average loss: 0.1463
# EPOCH 1939/2000
# Average loss: 0.1462
# EPOCH 1940/2000
# Average loss: 0.1460
# EPOCH 1941/2000
# Average loss: 0.1457
# EPOCH 1942/2000
# Average loss: 0.1456
# EPOCH 1943/2000
# Average loss: 0.1460
# EPOCH 1944/2000
# Average loss: 0.1448
# EPOCH 1945/2000
# Average loss: 0.1461
# EPOCH 1946/2000
# Average loss: 0.1449
# EPOCH 1947/2000
# Average loss: 0.1460
# EPOCH 1948/2000
# Average loss: 0.1454
# EPOCH 1949/2000
# Average loss: 0.1454
# EPOCH 1950/2000
# Average loss: 0.1447
# EPOCH 1951/2000
# Average loss: 0.1442
# EPOCH 1952/2000
# Average loss: 0.1468
# EPOCH 1953/2000
# Average loss: 0.1450
# EPOCH 1954/2000
# Average loss: 0.1445
# EPOCH 1955/2000
# Average loss: 0.1456
# EPOCH 1956/2000
# Average loss: 0.1450
# EPOCH 1957/2000
# Average loss: 0.1450
# EPOCH 1958/2000
# Average loss: 0.1461
# EPOCH 1959/2000
# Average loss: 0.1451
# EPOCH 1960/2000
# Average loss: 0.1458
# EPOCH 1961/2000
# Average loss: 0.1462
# EPOCH 1962/2000
# Average loss: 0.1455
# EPOCH 1963/2000
# Average loss: 0.1458
# EPOCH 1964/2000
# Average loss: 0.1453
# EPOCH 1965/2000
# Average loss: 0.1448
# EPOCH 1966/2000
# Average loss: 0.1456
# EPOCH 1967/2000
# Average loss: 0.1456
# EPOCH 1968/2000
# Average loss: 0.1442
# EPOCH 1969/2000
# Average loss: 0.1444
# EPOCH 1970/2000
# Average loss: 0.1438
# EPOCH 1971/2000
# Average loss: 0.1445
# EPOCH 1972/2000
# Average loss: 0.1446
# EPOCH 1973/2000
# Average loss: 0.1436
# EPOCH 1974/2000
# Average loss: 0.1450
# EPOCH 1975/2000
# Average loss: 0.1446
# EPOCH 1976/2000
# Average loss: 0.1442
# EPOCH 1977/2000
# Average loss: 0.1425
# EPOCH 1978/2000
# Average loss: 0.1437
# EPOCH 1979/2000
# Average loss: 0.1438
# EPOCH 1980/2000
# Average loss: 0.1444
# EPOCH 1981/2000
# Average loss: 0.1441
# EPOCH 1982/2000
# Average loss: 0.1445
# EPOCH 1983/2000
# Average loss: 0.1424
# EPOCH 1984/2000
# Average loss: 0.1442
# EPOCH 1985/2000
# Average loss: 0.1440
# EPOCH 1986/2000
# Average loss: 0.1430
# EPOCH 1987/2000
# Average loss: 0.1430
# EPOCH 1988/2000
# Average loss: 0.1437
# EPOCH 1989/2000
# Average loss: 0.1430
# EPOCH 1990/2000
# Average loss: 0.1426
# EPOCH 1991/2000
# Average loss: 0.1444
# EPOCH 1992/2000
# Average loss: 0.1439
# EPOCH 1993/2000
# Average loss: 0.1433
# EPOCH 1994/2000
# Average loss: 0.1436
# EPOCH 1995/2000
# Average loss: 0.1441
# EPOCH 1996/2000
# Average loss: 0.1438
# EPOCH 1997/2000
# Average loss: 0.1438
# EPOCH 1998/2000
# Average loss: 0.1428
# EPOCH 1999/2000
# Average loss: 0.1428
# EPOCH 2000/2000
# Average loss: 0.1433

# %%
save_checkpoint(model, {
    'vocab_size': vocab_size,
    'hidden_dim': hidden_dim,
    'seq_len': seq_len,
    'num_blocks': num_blocks
}, optimizer, losses, filename="shakespeare/checkpoints/mixer/checkpoint_tMLP.pth")
# Out:
# Checkpoint saved with loss 0.1467

# %%
model, optimizer, losses = load_checkpoint("shakespeare/checkpoints/mixer/checkpoint_tMLP.pth")
# Out:
# {'vocab_size': 65, 'hidden_dim': 512, 'seq_len': 512, 'num_blocks': 6}
# Checkpoint loaded: loss 0.1467

# %%
# Plot the loss curve

temp = []
for i in range(0, len(losses), num_batches):
    epoch = losses[i:i+num_batches]
    avg = np.mean(epoch)
    temp.append(avg)

plt.figure(figsize=(20, 6))
plt.plot(temp, label="Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.legend()
plt.show()

# %%
import torch
import torch.nn.functional as F

def evaluate(model, prompt, generation_length=128, seq_len=128):
    """
    Generates text from the model given a prompt.
    
    Args:
        model: The trained MLPMixer model.
        prompt (str): The prompt to condition generation on.
        generation_length (int): Number of characters to generate.
        seq_len (int): The sequence length the model expects.
        temperature (float): Temperature parameter for sampling.
    
    Returns:
        str: The prompt plus the generated text.
    """
    model.eval()  # Set model to evaluation mode
    # Convert prompt into a list of token ids
    tokens = [char2id[c] for c in prompt]
    
    # Autoregressive generation loop
    with torch.no_grad():
        for _ in range(generation_length):
            # Prepare the input context:
            # If the context is shorter than seq_len, pad to the left (using the token for space)
            if len(tokens) < seq_len:
                # pad with the space character (or any chosen pad token)
                padded = [char2id[' ']] * (seq_len - len(tokens)) + tokens
            else:
                padded = tokens[-seq_len:]
            
            # Convert to a tensor and add batch dimension
            x = torch.tensor(padded, dtype=torch.long, device=device).unsqueeze(0)  # shape (1, seq_len)
            
            # Get logits from the model; output shape is (1, seq_len, vocab_size)
            logits = model(x)

            predictions = torch.argmax(logits, dim=-1)

            #intermediate string output
            # temp = [id2char[t] for t in predictions[0].tolist()]
            # print(''.join(temp))

            next_token = predictions[0][-1].item()
            tokens.append(next_token)
    
    # Convert the list of tokens back to a string
    generated_text = ''.join([id2char[t] for t in tokens])
    return generated_text

# Example usage:
prompt = "We are accounted poor citizens, the patricians good.\nWhat authority surfeits on would relieve us:\nif they would yield us but the superfluity, while it were wholesome,\nwe might guess they relieved us humanely;"
print(len(prompt))
generated = evaluate(model, prompt, generation_length=2048, seq_len=seq_len)
print("Generated text:")
print(generated)
# Out:
# 208
# Generated text:
# We are accounted poor citizens, the patricians good.
# What authority surfeits on would relieve us:
# if they would yield us but the superfluity, while it were wholesome,
# we might guess they relieved us humanely;
# but there are the precise let ear creent.
#
# GLOUCESTER:
# The first the first thou shalt not stay things
# Of the appetite of air,
# And call them affrom the desire and death.
#
# LUCENTIO:
# I do are heart in love.
#
# Second Gentleman:
# Who there's heaven, and that wish mine honour,
# And be true so part to her,
# Which you are to be speech you all intend;
# But such as we love already, do your suit me,
# As how stoop'd his queen as smy soul,
# Do him wy in 'sheer disterited to hell under that
# All see the day is the surly night,
# And in his tutorship them souls be rich,
# Or my heart be accused down to her flesh,
# Which for slack, that he to yur marriage,
# The present wrails may and make the ropes
# Of my country's worth and brother and for her,
# A heart the rest in person are can ever
# I never of the king.
#
# ROMEO:
# Who should take me with you, with an shepherd marriage?
#
# PETRUCHIO:
# It is the quarrel as hot, that you are,
# That would you may wise appear souls?
#
# LUCENTIO:
# He knewiegness to his charge her the ends:
# How camest thou hast the people's of the barren;
# For shall I will under them prefer thee?
#
# FRANIO:
# O Clifford, my good lord:
# I do beseech you will for the in prince,
# And all feel bear the duke, or work, have I,
# Thou since, my to thou must, the commends him in the sun
# Should be ease answer'd to word good the good will!
#
# RANCIO:
# Nay, then, good sir; and so I take my leave
# To have for me all of this father's lands.
#
# PRINCE EDWARD:
# Methinks audo I remember keep at his age,
# You present bankrupt on Richard's friend,
# When he shall miss'd us please the ripe the Volsces,
# And doth enough are so fast and storms,
# And therefore ends milling one of the world,
# When he shut all to meet him and this life.
#
# CATESBY:
# He will be ther, that thy father in his face,
# That thou shalt not still make ease.
#
# MENENIUS:
# I go.
#
# ROMEO:
# Well, well, sir, he may be a king, Warless I see,
# My gracious lord,
# Which I have mischive, but not desperate
# That signity, 'with a charment of this face,
# To see you so fair queen and his noble consent
# To have you out of such as have; but
