# %% [markdown]
# ### Setup & Definition

# %%
import torch
import random
import torch.optim as optim
import torch.nn as nn
import numpy as np
from tqdm.notebook import tqdm
from matplotlib import pyplot as plt

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

#deallocate all cuda memory
torch.cuda.empty_cache()

#print cuda memory
print(torch.cuda.memory_allocated())
# Out:
# cuda
# 164682752

# %%
class AUNNModel(nn.Module):
    def __init__(
        self, 
        embedding_dim:int, 
        output_dim:int, 
        num_layers:int, 
        hidden_dim:int):        

        assert num_layers >= 2, "Number of layers must be at least 2"

        super(AUNNModel, self).__init__() 
    
        self.embedding_dim = embedding_dim
        self.output_dim = output_dim
        self.num_layers = num_layers
        self.hidden_dim = hidden_dim

        # Input Layer
        self.input_layer =  nn.Linear(self.embedding_dim, self.hidden_dim)

        # Hidden Layers
        self.layers = nn.ModuleList()
        for _ in range(self.num_layers - 2):  # Exclude input and output layers
            self.layers.append(nn.Sequential(
                nn.Linear(self.hidden_dim, self.hidden_dim),
                nn.SiLU()
            ))

        # Output Layer
        self.output_layer = nn.Linear(self.hidden_dim, self.output_dim)

        # Initialize weights
        self._initialize_weights()

    def _initialize_weights(self):

        for m in self.modules():
            if isinstance(m, nn.Linear):
                # Kaiming He initialization for Swish activation
                nn.init.kaiming_normal_(m.weight)
                if m.bias is not None:
                    nn.init.zeros_(m.bias)

    def count_params(self):
        return sum(p.numel() for p in self.parameters() if p.requires_grad)

    '''
    def encode(self, x: torch.Tensor):

        dim = self.embedding_dim
        assert dim % 2 == 0, "Encoding dimension (dim) must be even."

        # Determine the number of frequencies
        num_frequencies = dim // 2

        # Frequencies corresponding to powers of two, starting from 2^2
        frequency_powers = torch.arange(2, 2 + num_frequencies, dtype=torch.float32, device=x.device)
        frequencies = 2 ** frequency_powers  # Shape: [num_frequencies]

        # Compute the angles: [N, num_frequencies]
        x = x.unsqueeze(1)  # Shape: [N, 1]
        angles = (2 * torch.pi * x) / frequencies  # Broadcasting over x and frequencies

        # Compute the positional encodings
        encoding = torch.zeros(x.size(0), dim, device=x.device)
        encoding[:, 0::2] = torch.sin(angles)  # Even indices: sin
        encoding[:, 1::2] = torch.cos(angles)  # Odd indices: cos

        return encoding
    '''

    def encode(self, x: torch.Tensor): #binary encoding
        dim = self.embedding_dim
        encoding = ((x.unsqueeze(1) >> torch.arange(dim, device=x.device)) & 1).to(torch.float32)
        return encoding

    def forward(self, indices):
        
        x = self.encode(indices)
        x = self.input_layer(x)
        x = x + nn.SiLU()(x)

        for layer in self.layers:
            x = x + layer(x)  # MLP output with skip connection

        x = self.output_layer(x)
        return x

# %%
# Define a function to save the model checkpoint
def save_checkpoint(model, params, optimizer, losses, filename="checkpoint.pth"):
    
    checkpoint = {
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'losses': losses,
        'params':{}
    }

    keys = ['embedding_dim', 'output_dim', 'num_layers', 'hidden_dim']
    assert all(k in params for k in keys)
    for k in keys:
        checkpoint['params'][k] = params[k]

    torch.save(checkpoint, filename)
    print(f"Checkpoint saved with loss {losses[-1]:.4f}")

# %%
def load_checkpoint(filename="checkpoint.pth"):

    checkpoint = torch.load(filename, weights_only=True)
    
    params = checkpoint['params']
    model = AUNNModel(**params)
    model.load_state_dict(checkpoint['model_state_dict'])
    model.to(device)
    
    optimizer = optim.AdamW(model.parameters())
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    
    losses = checkpoint['losses']

    print(f"Checkpoint loaded: loss {losses[-1]:.4f}")

    return model, optimizer, losses

# %% [markdown]
# ### Train

# %%
# Hyperparameters

embedd_dim = 64
num_layers = 4    # Must be even and at least 2 (bc of skip connections)
hidden_dim = 128   # Size of hidden layers
batch_size = 8192  # Adjust batch size for efficiency
num_epochs = 500

# %%
#really long repeated pattern
# text = "abc" * 10_000  # Repeat the sequence to create a long string

#really long random pattern
options = ['|aaa','|bbb','|ccc']
num_sequences = 15_000
num_repeats = num_sequences * len(options)
num_repeats = num_repeats - num_repeats % batch_size # ensure num_repeats is a multiple of batch_size
options = options * num_repeats
random.seed(42)
random.shuffle(options)
text = ''.join(options)
print(len(text))
# Out:
# 491520

# %%
vocab = sorted(set(text))
token_to_id = {token: id for id, token in enumerate(vocab)}
id_to_token = {id: token for token, id in token_to_id.items()}
token_ids = [token_to_id[char] for char in text]
token_ids = torch.tensor(token_ids, dtype=torch.long).to(device)
indices = torch.arange(len(token_ids)).to(device)

# %%
# Initialize the model, loss function, and optimizer
model = AUNNModel(embedd_dim, len(vocab), num_layers, hidden_dim).to(device)
print(f"Model has {model.count_params():,} parameters")
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters())
losses = []
accuracies = []
# Out:
# Model has 41860 parameters

# %%
# Training Loop
total_steps = len(text) // batch_size
if len(text) % batch_size != 0:
    total_steps += 1

for epoch in tqdm(range(num_epochs)):
    model.train()
    start_idxs = list(range(0, len(text), batch_size))
    # random.seed(epoch)
    # random.shuffle(start_idxs)
    for start_idx in start_idxs:
        end_idx = start_idx + batch_size
        
        inputs = indices[start_idx:end_idx]
        targets = token_ids[start_idx:end_idx]

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        cur_loss = loss.item()
        losses.append(cur_loss)

        #calculate accuracy
        _, predicted = torch.max(outputs, 1)
        correct = (predicted == targets).sum().item()
        cur_acc = correct / batch_size
        accuracies.append(cur_acc)

        # recent_avg_loss = sum(losses[-100:]) / 100
        # recent_avg_acc = sum(accuracies[-100:]) / 100
        # print(f"Loss: {recent_avg_loss:.6f}, Accuracy: {recent_avg_acc:.4f}", end="\r")

    avg_loss = sum(losses[-len(start_idxs):]) / len(start_idxs)
    avg_acc = sum(accuracies[-len(start_idxs):]) / len(start_idxs)
    print(f"Epoch [{epoch+1}/{num_epochs}] completed, Average Loss: {avg_loss:.6f}, Average Accuracy: {avg_acc:.4f}")
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch [1/500] completed, Average Loss: 1.099929, Average Accuracy: 0.4547
# Epoch [2/500] completed, Average Loss: 0.977896, Average Accuracy: 0.4991
# Epoch [3/500] completed, Average Loss: 0.940851, Average Accuracy: 0.5014
# Epoch [4/500] completed, Average Loss: 0.864863, Average Accuracy: 0.5029
# Epoch [5/500] completed, Average Loss: 0.878178, Average Accuracy: 0.5018
# Epoch [6/500] completed, Average Loss: 0.845822, Average Accuracy: 0.5018
# Epoch [7/500] completed, Average Loss: 0.844185, Average Accuracy: 0.5007
# Epoch [478/500] completed, Average Loss: 0.726168, Average Accuracy: 0.6437
# Epoch [479/500] completed, Average Loss: 0.729753, Average Accuracy: 0.6402
# Epoch [480/500] completed, Average Loss: 0.728698, Average Accuracy: 0.6418
# Epoch [481/500] completed, Average Loss: 0.733737, Average Accuracy: 0.6370
# Epoch [482/500] completed, Average Loss: 0.728595, Average Accuracy: 0.6422
# Epoch [483/500] completed, Average Loss: 0.731685, Average Accuracy: 0.6383
# Epoch [484/500] completed, Average Loss: 0.728103, Average Accuracy: 0.6433
# Epoch [485/500] completed, Average Loss: 0.730918, Average Accuracy: 0.6392
# Epoch [486/500] completed, Average Loss: 0.730162, Average Accuracy: 0.6412
# Epoch [487/500] completed, Average Loss: 0.732796, Average Accuracy: 0.6382
# Epoch [488/500] completed, Average Loss: 0.733687, Average Accuracy: 0.6380
# Epoch [489/500] completed, Average Loss: 0.733395, Average Accuracy: 0.6377
# Epoch [490/500] completed, Average Loss: 0.733215, Average Accuracy: 0.6377
# Epoch [491/500] completed, Average Loss: 0.728653, Average Accuracy: 0.6411
# Epoch [492/500] completed, Average Loss: 0.728071, Average Accuracy: 0.6411
# Epoch [493/500] completed, Average Loss: 0.723077, Average Accuracy: 0.6461
# Epoch [494/500] completed, Average Loss: 0.722609, Average Accuracy: 0.6459
# Epoch [495/500] completed, Average Loss: 0.721254, Average Accuracy: 0.6478
# Epoch [496/500] completed, Average Loss: 0.724900, Average Accuracy: 0.6440
# Epoch [497/500] completed, Average Loss: 0.726905, Average Accuracy: 0.6438
# Epoch [498/500] completed, Average Loss: 0.731841, Average Accuracy: 0.6400
# Epoch [499/500] completed, Average Loss: 0.734479, Average Accuracy: 0.6385
# Epoch [500/500] completed, Average Loss: 0.734787, Average Accuracy: 0.6366

# %%
params = {
    'embedding_dim': embedd_dim,
    'output_dim': len(vocab),
    'num_layers': num_layers,
    'hidden_dim': hidden_dim
}
save_checkpoint(model, params, optimizer, losses, filename="sequence/checkpoint.pth")
# Out:
# Checkpoint saved with loss 0.7334

# %%
model, optimizer, losses = load_checkpoint(filename="sequence/checkpoint.pth")
# Out:
# Checkpoint loaded: loss 0.7334

# %%
print(sum(accuracies) / len(accuracies))
# Out:
# 0.5871401692708333

# %%
# Plot the loss curves
plt.figure(figsize=(40, 6))
plt.plot(losses, label="Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.legend()
plt.show()

# Plot the accuracy curves
plt.figure(figsize=(40, 6))
plt.plot(accuracies, label="Training Accuracy")
plt.xlabel("Steps")
plt.ylabel("Accuracy")
plt.title("Training Accuracy")
plt.legend()
plt.show()

# %%
# Generate Text Function
def generate_text(model, start_index, length):
    model.eval()
    generated_tokens = []
    indices = torch.arange(start_index, start_index + length).to(device)
    with torch.no_grad():
        outputs = model(indices)
        _, predicted = torch.max(outputs, 1)
    for id in predicted:
        token = id_to_token.get(id.item(), "<UNK>")
        generated_tokens.append(token)
    return ''.join(generated_tokens)

# Generate text starting from the next index after the training data
start_index = 0
generated_text = generate_text(model, start_index=start_index, length=100)
print("Generated Text:")
print(generated_text)

# Generate text starting from the next index after the training data
start_index = len(text) - 50
generated_text = generate_text(model, start_index=start_index, length=100)
print("Generated Text:")
before_end = generated_text[:50]
after_end = generated_text[50:]
print(f"{before_end}_{after_end}")
# Out:
# Generated Text:
# |aaa|ccc|aaa|ccc|cac|aaa|aaa|ccc|bbb|aaa|bbb|aaa|ccb|ccc|ccc|caa|bbb|ccc|ccc|ccc|ccc|bbb|aaa|ccc|bbb
# Generated Text:
# cc|aaa|aaa|aaa|bbb|bbb|aaa|bbb|aaa|aaa|aaa|bbb|bbb_|aaa|aaa|bbb|aaa|aaa|aaa|bbb|aaa|aaa|baa|bbb|bbb|a

# %%
N = len(text) - 1
preds = generate_text(model, start_index=N+1, length=50_000)
count = {}
for char in preds:
    count[char] = count.get(char, 0) + 1

plt.bar(count.keys(), count.values())
plt.show()

# %%
N = len(text) - 1

#see value before conditioning
generated_text = generate_text(model, start_index=N+1, length=150)
print("Original Text:")
print(generated_text) # "|a..."
print("")

#conditioning the model
conditioning_targets = ['|','b']  # Desired tokens at N+1 and N+2, this also works if you use "|c" or "|a" as conditioning_targets
conditioning_positions = [N+1, N+2]
# conditioning_targets = ['c','a','b'] #show conditioning works on discontinuous tokens
# conditioning_positions = [N+2, N+7, N+12]

conditioning_target_indices = [token_to_id[token] for token in conditioning_targets]
targets_tensor = torch.tensor(conditioning_target_indices, dtype=torch.long).to(device)
positions_tensor = torch.tensor(conditioning_positions).to(device)

criterion = nn.CrossEntropyLoss()
conditioning_optimizer = optim.SGD(model.parameters(), lr=1e-3)
model.train()
step = 0

while True:
    conditioning_optimizer.zero_grad()
    outputs = model(positions_tensor)
    loss = criterion(outputs, targets_tensor)
    loss.backward()
    conditioning_optimizer.step()
    print(f"Conditioning Step {step+1}, Loss: {loss.item():.6f}")
    #get new outputs
    generated_tokens = []
    outputs = model(positions_tensor)
    predicted = torch.argmax(outputs, dim=1)
    for id in predicted:
        token = id_to_token.get(id.item(), "<UNK>")
        generated_tokens.append(token)
    print("".join(generated_tokens))
    if generated_tokens == conditioning_targets:
        break

#see value after conditioning
generated_text = generate_text(model, start_index=N+1, length=150)
print("")
print("Text after conditioning:")
print(generated_text) # "|bbb|..." shows conditioning works because of new values for N+3 and N+4
# Out:
# Original Text:
# |aaa|aaa|bbb|aaa|aaa|aaa|bbb|aaa|aaa|baa|bbb|bbb|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|bbb|bbb|bbb|aaa|a
#
# Conditioning Step 1, Loss: 1.666578
# |a
# Conditioning Step 1, Loss: 0.920492
# |a
# Conditioning Step 1, Loss: 0.433380
# |b
#
# Text after conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|bbb|bbb|bbb|aaa|aaa|bbb|bbb|bbb|bbb|aaa|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|bbb|bbb|b

# %%
model, optimizer, losses = load_checkpoint(filename="sequence/checkpoint.pth")
# Out:
# Checkpoint loaded: loss 0.7334

# %%
print(token_to_id)
# Out:
# {'a': 0, 'b': 1, 'c': 2, '|': 3}

# %%
#assess performance of subsequent conditioning
random.seed(42)
options = ['|aaa','|bbb','|ccc']
sequences = options * 10
random.shuffle(sequences)
new_text = ''.join(sequences) #new text to condition on
print("target:")
print(new_text)


#now we'll condition the model, one letter at a time

criterion = nn.CrossEntropyLoss()
conditioning_optimizer = optim.SGD(model.parameters(), lr=1e-3)
model.train()
N = len(text)

for i, letter in enumerate(new_text):

    conditioning_optimizer.zero_grad()

    print("-"*50)

    idx = N + i
    print("conditioning on:")
    print(f"{"_"*i}{letter}{"_"*(len(new_text)-i-1)}")

    #see value before conditioning
    print("output before conditioning:")
    generated_text = generate_text(model, start_index=N, length=len(new_text))
    print(generated_text)

    while True:

        target_ids = [token_to_id[letter]]
        target_tensor = torch.tensor(target_ids, dtype=torch.long).to(device)
        positions = torch.tensor([idx]).to(device)
        outputs = model(positions)
        print(outputs)
        # print(outputs.shape)
        # print(target_tensor.shape)
        loss = criterion(outputs, target_tensor)
        loss.backward()
        conditioning_optimizer.step()
        print(f"Loss: {loss.item():.6f}")

        #see value after conditioning
        print("output after conditioning:")
        generated_text = generate_text(model, start_index=N, length=len(new_text))
        print(generated_text)

        predicted_letter = generated_text[i]
        print(f"{letter} -> {predicted_letter} ... {letter == predicted_letter}")
        if predicted_letter == letter:
            break    
        print('--')
# Out:
# target:
# |bbb|ccc|bbb|ccc|bbb|aaa|ccc|aaa|ccc|aaa|aaa|bbb|ccc|aaa|bbb|aaa|bbb|bbb|aaa|ccc|ccc|bbb|bbb|aaa|bbb|ccc|ccc|aaa|aaa|ccc
# --------------------------------------------------
# conditioning on:
# |_______________________________________________________________________________________________________________________
# output before conditioning:
# |aaa|aaa|bbb|aaa|aaa|aaa|bbb|aaa|aaa|baa|bbb|bbb|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# tensor([[-5.1244, -8.0417, -3.8578, 48.4877]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |aaa|aaa|bbb|aaa|aaa|aaa|bbb|aaa|aaa|baa|bbb|bbb|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _b______________________________________________________________________________________________________________________
# output before conditioning:
# |aaa|aaa|bbb|aaa|aaa|aaa|bbb|aaa|aaa|baa|bbb|bbb|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# tensor([[  2.2508,  -1.0062,  -0.9524, -31.4970]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 3.333157
# output after conditioning:
# |bbb|bbb|bbb|bbb|aaa|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|aab|bbb|aaa|aaa|aaa|bbb|bbb|bbb|bbb|aaa|aaa|aaa|bba
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# __b_____________________________________________________________________________________________________________________
# output before conditioning:
# |bbb|bbb|bbb|bbb|aaa|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|aab|bbb|aaa|aaa|aaa|bbb|bbb|bbb|bbb|aaa|aaa|aaa|bba
# tensor([[  0.5851,   0.6252,  -1.0974, -30.7999]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.760463
# output after conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# ___b____________________________________________________________________________________________________________________
# output before conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb
# tensor([[  0.0788,   1.9143,  -0.7489, -32.8080]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.206408
# output after conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# ____|___________________________________________________________________________________________________________________
# output before conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb
# tensor([[-5.6913, -2.9537, -3.3431, 39.8106]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _____c__________________________________________________________________________________________________________________
# output before conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb
# tensor([[ -0.0893,   2.1793,  -0.0553, -25.5633]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 2.425593
# output after conditioning:
# |bbb|ccc|bbb|ccc|ccc|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|ccc|bbb|ccc|aaa|aaa|bbb|bbb|bbb|bbb|aab|aaa|bbb|bba
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# ______c_________________________________________________________________________________________________________________
# output before conditioning:
# |bbb|ccc|bbb|ccc|ccc|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|ccc|bbb|ccc|aaa|aaa|bbb|bbb|bbb|bbb|aab|aaa|bbb|bba
# tensor([[ -0.2675,   0.7350,   1.4773, -25.2052]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.501182
# output after conditioning:
# |bbb|ccc|bbb|ccc|ccc|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|ccc|bbb|ccc|aaa|aaa|bbb|bbb|bbb|ccc|aaa|cca|bbb|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# _______c________________________________________________________________________________________________________________
# output before conditioning:
# |bbb|ccc|bbb|ccc|ccc|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|ccc|bbb|ccc|aaa|aaa|bbb|bbb|bbb|ccc|aaa|cca|bbb|aaa
# tensor([[ -0.1249,   0.6380,   2.5637, -25.6972]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.193709
# output after conditioning:
# |bbb|ccc|bbb|ccc|ccc|aaa
________
# output before conditioning:
# |bbb|ccc|bbb|ccc|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bba|aab|ccc|bbb|ccc|aaa|aaa|bbb|bba|bbb|aac|bab|aaa|bbb|aaa
# tensor([[ -1.6919,   1.2969,  -3.0836, -31.5323]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 4.441486
# output after conditioning:
# |bbb|ccc|bbb|ccc|bbb|aaa|bbb|cca|bbb|bbb|bbb|ccc|bbb|aaa|bbb|aaa|aaa|ccc|bbb|ccc|aaa|aaa|bbb|aaa|bbb|ccc|aaa|caa|bbb|aaa
# c -> b ... False
# --
# tensor([[ -1.7799,  -0.0970,  -1.5382, -31.3705]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 1.793662
# output after conditioning:
# |ccc|ccc|ccc|ccc|ccc|aac|ccc|ccc|bbb|ccc|bbb|ccc|ccc|aaa|ccc|ccc|aac|ccc|aaa|ccc|aaa|aaa|ccc|ccc|ccc|ccc|ccc|ccc|aaa|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# __________________________c_____________________________________________________________________________________________
# output before conditioning:
# |ccc|ccc|ccc|ccc|ccc|aac|ccc|ccc|bbb|ccc|bbb|ccc|ccc|aaa|ccc|ccc|aac|ccc|aaa|ccc|aaa|aaa|ccc|ccc|ccc|ccc|ccc|ccc|aaa|aaa
# tensor([[ -2.1506,  -2.4716,   1.1885, -31.0435]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.059396
# output after conditioning:
# |ccc|ccc|ccc|ccc|ccc|ccc|ccc|ccc|bbb|ccc|bbb|ccc|ccc|aaa|ccc|ccc|ccc|ccc|aaa|ccc|aaa|aaa|ccc|ccc|ccc|ccc|ccc|ccc|aaa|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# ___________________________c____________________________________________________________________________________________
# output before conditioning:
# |ccc|ccc|ccc|ccc|ccc|ccc|ccc|ccc|bbb|ccc|bbb|ccc|ccc|aaa|ccc|ccc|ccc|ccc|aaa|ccc|aaa|aaa|ccc|ccc|ccc|ccc|ccc|ccc|aaa|aaa
# tensor([[ -1.6586,  -1.9678,   1.8045, -32.8062]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.052904
# output after conditioning:
# |ccc|ccc|ccc|ccc|ccc|ccc|ccc|ccc|bbb|ccc|bbb|ccc|ccc|aaa|ccc|ccc|ccc|ccc|aaa|ccc|aaa|aaa|ccc|ccc|ccc|ccc|ccc|ccc|aaa|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# ____________________________|___________________________________________________________________________________________
# output before conditioning:
# |ccc|ccc|ccc|ccc|ccc|ccc|ccc|ccc|bbb|ccc|bbb|ccc|ccc|aaa|ccc|ccc|ccc|ccc|aaa|ccc|aaa|aaa|ccc|ccc|ccc|ccc|ccc|ccc|aaa|aaa
# tensor([[-9.3807, -8.4720, -1.7908, 31.3414]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |ccc|ccc|ccc|ccc|ccc|ccc|ccc|ccc|bbb|ccc|bbb|ccc|ccc|aaa|ccc|ccc|ccc|ccc|aaa|ccc|aaa|aaa|ccc|ccc|ccc|ccc|ccc|ccc|aaa|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _____________________________a__________________________________________________________________________________________
# output before conditioning:
# |ccc|ccc|ccc|ccc|ccc|ccc|ccc|ccc|bbb|ccc|bbb|ccc|ccc|aaa|ccc|ccc|ccc|ccc|aaa|ccc|aaa|aaa|ccc|ccc|ccc|ccc|ccc|ccc|aaa|aaa
# tensor([[ -1.0666,  -2.8082,   0.9584, -39.2630]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 2.169205
# output after conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|ccc|aaa|bbb|ccc|bbb|ccc|bbb|aaa|ccc|aaa|aaa|ccc|aaa|ccc|aaa|aaa|ccc|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ______________________________a_________________________________________________________________________________________
# output before conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|ccc|aaa|bbb|ccc|bbb|ccc|bbb|aaa|ccc|aaa|aaa|ccc|aaa|ccc|aaa|aaa|ccc|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# tensor([[  0.0673,  -2.8165,  -0.0790, -39.1583]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.652226
# output after conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|bbb|aaa|bbb|ccc|baa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# _______________________________a________________________________________________________________________________________
# output before conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|bbb|aaa|bbb|ccc|baa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# tensor([[  1.1620,  -2.4303,  -0.1871, -39.9024]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.252315
# output after conditioning:
# |cac|ccc|aaa|ccc|ccc|aaa|ccc|aaa|bbb|aaa|bbb|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ________________________________|_______________________________________________________________________________________
# output before conditioning:
# |cac|ccc|aaa|ccc|ccc|aaa|ccc|aaa|bbb|aaa|bbb|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# tensor([[-7.6190, -6.2217, -3.9770, 31.2437]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |cac|ccc|aaa|ccc|ccc|aaa|ccc|aaa|bbb|aaa|bbb|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _________________________________c______________________________________________________________________________________
# output before conditioning:
# |cac|ccc|aaa|ccc|ccc|aaa|ccc|aaa|bbb|aaa|bbb|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# tensor([[ -1.2403,   0.0454,  -1.3284, -34.8660]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 1.798845
# output after conditioning:
# |ccc|ccc|aac|ccc|ccc|aaa|ccc|aaa|ccc|ccc|ccc|ccc|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|aaa|aac|aaa|aaa|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# __________________________________c_____________________________________________________________________________________
# output before conditioning:
# |ccc|ccc|aac|ccc|ccc|aaa|ccc|aaa|ccc|ccc|ccc|ccc|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|aaa|aac|aaa|aaa|aaa
# tensor([[ -1.5217,  -1.1491,   0.0703, -34.4496]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.404737
# output after conditioning:
# |ccc|ccc|ccc|ccc|ccc|aaa|ccc|aaa|ccc|ccc|ccc|ccc|ccc|aaa|ccc|aaa|aac|ccc|aaa|aaa|aaa|aaa|ccc|aaa|ccc|ccc|ccc|aaa|aaa|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# ___________________________________c____________________________________________________________________________________
# output before conditioning:
# |ccc|ccc|ccc|ccc|ccc|aaa|ccc|aaa|ccc|ccc|ccc|ccc|ccc|aaa|ccc|aaa|aac|ccc|aaa|aaa|aaa|aaa|ccc|aaa|ccc|ccc|ccc|aaa|aaa|aaa
# tensor([[ -1.3564,  -1.1927,   1.0653, -34.6124]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.176753
# output after conditioning:
# |ccc|ccc|ccc|ccc|ccc|aaa|ccc|aaa|ccc|ccc|ccc|ccc|ccc|aaa|ccc|aaa|ccc|ccc|aaa|ccc|aaa|aaa|ccc|aaa|ccc|ccc|ccc|aaa|aaa|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# ____________________________________|___________________________________________________________________________________
# output before conditioning:
# |ccc|ccc|ccc|ccc|ccc|aaa|ccc|aaa|ccc|ccc|ccc|ccc|ccc|aaa|ccc|aaa|ccc|ccc|aaa|ccc|aaa|aaa|ccc|aaa|ccc|ccc|ccc|aaa|aaa|aaa
# tensor([[-5.9522, -8.0265, -1.4573, 28.8764]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |ccc|ccc|ccc|ccc|ccc|aaa|ccc|aaa|ccc|ccc|ccc|ccc|ccc|aaa|ccc|aaa|ccc|ccc|aaa|ccc|aaa|aaa|ccc|aaa|ccc|ccc|ccc|aaa|aaa|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _____________________________________a__________________________________________________________________________________
# output before conditioning:
# |ccc|ccc|ccc|ccc|ccc|aaa|ccc|aaa|ccc|ccc|ccc|ccc|ccc|aaa|ccc|aaa|ccc|ccc|aaa|ccc|aaa|aaa|ccc|aaa|ccc|ccc|ccc|aaa|aaa|aaa
# tensor([[ -0.8670,  -2.4137,   0.4890, -29.1595]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 1.628054
# output after conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|aaa|ccc|aaa|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ______________________________________a_________________________________________________________________________________
# output before conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|aaa|ccc|aaa|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa
# tensor([[  0.4739,  -2.4633,  -0.6161, -29.0003]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.328769
# output after conditioning:
# |ccc|aaa|aaa|cca|ccc|aaa|ccc|aaa|ccc|aaa|ccc|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# _______________________________________a________________________________________________________________________________
# output before conditioning:
# |ccc|aaa|aaa|cca|ccc|aaa|ccc|aaa|ccc|aaa|ccc|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# tensor([[  1.2448,  -2.1269,  -0.6413, -29.7222]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.170568
# output after conditioning:
# |ccc|aaa|aaa|aaa|ccc|aaa|ccc|aaa|ccc|aaa|ccc|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ________________________________________|_______________________________________________________________________________
# output before conditioning:
# |ccc|aaa|aaa|aaa|ccc|aaa|ccc|aaa|ccc|aaa|ccc|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# tensor([[-7.6770, -6.7115, -3.7771, 39.6865]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |ccc|aaa|aaa|aaa|ccc|aaa|ccc|aaa|ccc|aaa|ccc|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _________________________________________a______________________________________________________________________________
# output before conditioning:
# |ccc|aaa|aaa|aaa|ccc|aaa|ccc|aaa|ccc|aaa|ccc|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# tensor([[ -1.7222,  -1.1897,  -0.8714, -30.0036]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 1.618350
# output after conditioning:
# |aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# __________________________________________a_____________________________________________________________________________
# output before conditioning:
# |aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# tensor([[ -0.6575,  -1.6020,  -1.4299, -29.9052]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.615586
# output after conditioning:
# |aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ___________________________________________a____________________________________________________________________________
# output before conditioning:
# |aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# tensor([[  0.2434,  -1.4088,  -1.1590, -30.7380]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.362992
# output after conditioning:
# |aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ____________________________________________|___________________________________________________________________________
# output before conditioning:
# |aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# tensor([[-5.2117, -9.5138, -5.1515, 46.0093]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _____________________________________________b__________________________________________________________________________
# output before conditioning:
# |aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# tensor([[  0.4522,  -4.4659,  -2.7525, -22.0166]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 4.964839
# output after conditioning:
# |aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# b -> a ... False
# --
# tensor([[ -0.7403,  -3.1403,  -2.8581, -21.6349]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 2.591484
# output after conditioning:
# |aaa|aac|aaa|ccc|aaa|aaa|ccc|aaa|bbb|bbb|bbb|bbb|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# ______________________________________________b_________________________________________________________________________
# output before conditioning:
# |aaa|aac|aaa|ccc|aaa|aaa|ccc|aaa|bbb|bbb|bbb|bbb|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa
# tensor([[ -2.8627,  -0.7862,  -3.1298, -20.9262]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.199953
# output after conditioning:
# |aaa|aac|aaa|ccc|aaa|aaa|ccc|aaa|bbb|bbb|bbb|bbb|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# _______________________________________________b________________________________________________________________________
# output before conditioning:
# |aaa|aac|aaa|ccc|aaa|aaa|ccc|aaa|bbb|bbb|bbb|bbb|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa
# tensor([[ -2.4852,  -0.0745,  -2.9051, -22.5295]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.138655
# output after conditioning:
# |aaa|aac|bbb|ccc|aaa|aaa|ccc|aaa|bbb|bbb|bbb|bbb|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# ________________________________________________|_______________________________________________________________________
# output before conditioning:
# |aaa|aac|bbb|ccc|aaa|aaa|ccc|aaa|bbb|bbb|bbb|bbb|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa
# tensor([[-8.5985, -8.6711, -4.8577, 38.0676]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |aaa|aac|bbb|ccc|aaa|aaa|ccc|aaa|bbb|bbb|bbb|bbb|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _________________________________________________c______________________________________________________________________
# output before conditioning:
# |aaa|aac|bbb|ccc|aaa|aaa|ccc|aaa|bbb|bbb|bbb|bbb|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa
# tensor([[ -1.3043,  -1.8855,  -2.5437, -30.3871]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 1.853952
# output after conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aaa|aaa|aaa|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# __________________________________________________c_____________________________________________________________________
# output before conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aaa|aaa|aaa|aaa
# tensor([[ -2.2302,  -2.4840,  -1.2651, -29.9151]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.516712
# output after conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aaa|aaa|aaa|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# ___________________________________________________c____________________________________________________________________
# output before conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aaa|aaa|aaa|aaa
# tensor([[ -2.3471,  -2.5365,  -0.2658, -31.0877]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.205402
# output after conditioning:
# |ccc|ccc|bbc|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aac|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aac|aaa|ccc|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# ____________________________________________________|___________________________________________________________________
# output before conditioning:
# |ccc|ccc|bbc|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aac|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aac|aaa|ccc|aaa
# tensor([[-6.4499, -7.2977, -3.7090, 26.6336]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |ccc|ccc|bbc|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aac|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aac|aaa|ccc|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _____________________________________________________a__________________________________________________________________
# output before conditioning:
# |ccc|ccc|bbc|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aac|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aac|aaa|ccc|aaa
# tensor([[ -0.2571,  -2.7865,  -0.8067, -32.0886]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.504940
# output after conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ______________________________________________________a_________________________________________________________________
# output before conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aaa|aaa|aaa|aaa
# tensor([[  0.2637,  -2.7699,  -1.2116, -31.5963]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.244411
# output after conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# _______________________________________________________a________________________________________________________________
# output before conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aaa|aaa|aaa|aaa
# tensor([[  0.8569,  -2.5731,  -1.0823, -32.5188]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.162296
# output after conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ________________________________________________________|_______________________________________________________________
# output before conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aaa|aaa|aaa|aaa
# tensor([[-12.5166,  -8.5663,  -2.7390,  47.9059]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aaa|aaa|aaa|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _________________________________________________________b______________________________________________________________
# output before conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|ccc|bbb|aaa|aaa|aaa|aaa
# tensor([[ -4.0825,  -2.7412,   0.2260, -29.3073]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 3.030108
# output after conditioning:
# |ccc|aaa|bbb|ccc|ccc|aaa|ccc|aaa|bbb|bbb|bbb|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|aaa|aaa
# b -> c ... False
# --
# tensor([[ -3.9527,  -1.5198,  -0.8923, -28.9912]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 1.085452
# output after conditioning:
# |aab|bbb|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bab|aaa
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# __________________________________________________________b_____________________________________________________________
# output before conditioning:
# |aab|bbb|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bab|aaa
# tensor([[ -3.8582,   0.4320,  -2.6830, -28.1941]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.056459
# output after conditioning:
# |bab|bbb|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# ___________________________________________________________b____________________________________________________________
# output before conditioning:
# |bab|bbb|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa
# tensor([[ -3.4556,   0.8881,  -2.2956, -29.1880]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.052991
# output after conditioning:
# |bbb|bbb|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# ____________________________________________________________|___________________________________________________________
# output before conditioning:
# |bbb|bbb|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa
# tensor([[-8.7132, -4.7650, -6.8816, 40.6611]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |bbb|bbb|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _____________________________________________________________a__________________________________________________________
# output before conditioning:
# |bbb|bbb|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bbb|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa
# tensor([[ -0.8413,  -0.0986,  -3.8642, -32.2586]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 1.147485
# output after conditioning:
# |aaa|aaa|bbb|bba|aaa|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ______________________________________________________________a_________________________________________________________
# output before conditioning:
# |aaa|aaa|bbb|bba|aaa|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|aaa|aaa
# tensor([[ -0.1013,  -0.7924,  -3.7842, -32.1862]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.422761
# output after conditioning:
# |aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# _______________________________________________________________a________________________________________________________
# output before conditioning:
# |aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# tensor([[  0.6795,  -0.7986,  -3.4378, -32.6305]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.218617
# output after conditioning:
# |aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa|bbb|baa|bbb|bbb|bbb|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ________________________________________________________________|_______________________________________________________
# output before conditioning:
# |aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa|bbb|baa|bbb|bbb|bbb|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# tensor([[-3.3959, -5.1856, -3.4096, 40.9373]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa|bbb|baa|bbb|bbb|bbb|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _________________________________________________________________b______________________________________________________
# output before conditioning:
# |aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa|bbb|baa|bbb|bbb|bbb|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# tensor([[  2.2714,  -0.1397,  -0.1938, -20.7168]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 2.572111
# output after conditioning:
# |bbb|aaa|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|aaa|bbb|aaa|aaa|aaa|bba|aaa|bbb|bbb|bbb|aaa|aaa|aaa
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# __________________________________________________________________b_____________________________________________________
# output before conditioning:
# |bbb|aaa|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|aaa|bbb|aaa|aaa|aaa|bba|aaa|bbb|bbb|bbb|aaa|aaa|aaa
# tensor([[  1.0059,   1.0945,  -0.3556, -20.2070]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.765354
# output after conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|baa|bbb|aaa
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# ___________________________________________________________________b____________________________________________________
# output before conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|baa|bbb|aaa
# tensor([[  0.5302,   2.2181,   0.0234, -21.8100]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.259524
# output after conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# ____________________________________________________________________|___________________________________________________
# output before conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa
# tensor([[-3.6616, -0.4032, -3.0745, 26.0423]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _____________________________________________________________________b__________________________________________________
# output before conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa
# tensor([[  1.5045,   2.2448,   0.2556, -23.6401]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.478589
# output after conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|aaa|aaa|bbb|bba|bbb|bbb|bbb|bbb|bbb|bbb
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# ______________________________________________________________________b_________________________________________________
# output before conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|aaa|aaa|bbb|bba|bbb|bbb|bbb|bbb|bbb|bbb
# tensor([[  1.0292,   2.7793,   0.0678, -23.3591]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.215259
# output after conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|baa|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|bbb|bbb
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# _______________________________________________________________________b________________________________________________
# output before conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|baa|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|bbb|bbb
# tensor([[  1.0574,   3.3762,   0.3616, -23.7781]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.137545
# output after conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bba|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|bbb|bbb
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# ________________________________________________________________________|_______________________________________________
# output before conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bba|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|bbb|bbb
# tensor([[-6.4150, -0.8743, -5.2193, 43.8404]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bba|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|bbb|bbb
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _________________________________________________________________________a______________________________________________
# output before conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|bba|bbb|bbb|bbb|bbb|aaa|bbb|bbb|bbb|bbb|bbb|bbb|bbb|bbb|bbb
# tensor([[  0.6326,   2.8290,  -2.3333, -17.9718]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 2.306980
# output after conditioning:
# |bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|bbb|bbb|aaa|aaa|bbb|aaa|bbb|bbb|bbb|bbb|bbb|aaa
# a -> b ... False
# --
# tensor([[  1.5008,   1.9572,  -2.2899, -17.9863]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.955890
# output after conditioning:
# |bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# __________________________________________________________________________a_____________________________________________
# output before conditioning:
# |bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|aaa|aaa
# tensor([[  2.8708,   0.4706,  -2.2871, -17.8498]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.092077
# output after conditioning:
# |aab|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ___________________________________________________________________________a____________________________________________
# output before conditioning:
# |aab|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|aaa|aaa
# tensor([[  3.3375,   0.6838,  -1.7971, -18.7655]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# ...
# conditioning on:
# _______________________________________________________________________________________________a________________________
# output before conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa
# tensor([[  1.8104,  -2.0802,  -1.7628, -37.2041]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.047362
# output after conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ________________________________________________________________________________________________|_______________________
# output before conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa
# tensor([[-5.9266, -3.4051, -3.0976, 31.7490]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _________________________________________________________________________________________________b______________________
# output before conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa
# tensor([[ -0.2217,   1.2502,  -0.2332, -26.5150]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.375931
# output after conditioning:
# |bbb|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# __________________________________________________________________________________________________b_____________________
# output before conditioning:
# |bbb|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa
# tensor([[ -0.4632,   1.6150,  -0.4421, -26.3371]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.225532
# output after conditioning:
# |bbb|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|aaa|ccc|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# ___________________________________________________________________________________________________b____________________
# output before conditioning:
# |bbb|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|aaa|ccc|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa
# tensor([[ -0.3627,   2.1161,  -0.1652, -27.2574]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.170584
# output after conditioning:
# |bbb|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|aaa|ccc|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa
# b -> b ... True
# --------------------------------------------------
# conditioning on:
# ____________________________________________________________________________________________________|___________________
# output before conditioning:
# |bbb|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|aaa|ccc|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa
# tensor([[-5.3744, -1.1197, -3.0925, 14.7143]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |bbb|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|aaa|ccc|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _____________________________________________________________________________________________________c__________________
# output before conditioning:
# |bbb|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|bbb|aaa|ccc|aaa|aaa|aaa|aaa|bbb|bbb|aaa|aaa|bbb|aaa
# tensor([[ -0.2899,   1.6081,  -0.6533, -29.2418]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 2.487805
# output after conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|bbb|ccb|aaa|ccc|bbb|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# ______________________________________________________________________________________________________c_________________
# output before conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|bbb|bbb|bbb|bbb|aaa|bbb|aaa|bbb|ccc|aaa|ccc|aaa|aaa|aaa|aaa|bbb|ccb|aaa|ccc|bbb|aaa
# tensor([[ -0.3768,   0.5507,   0.5934, -28.7496]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.848929
# output after conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|ccc|bbb|bbb|bbb|aaa|bbb|aaa|ccc|ccc|aaa|ccc|aaa|aaa|aaa|aaa|bbb|ccc|aaa|ccc|bbb|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# _______________________________________________________________________________________________________c________________
# output before conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|ccc|bbb|bbb|bbb|aaa|bbb|aaa|ccc|ccc|aaa|ccc|aaa|aaa|aaa|aaa|bbb|ccc|aaa|ccc|bbb|aaa
# tensor([[ -0.2532,   0.3562,   1.6193, -29.3204]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.362215
# output after conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|ccc|bbb|bbb|bbb|aaa|bbb|aaa|ccc|ccc|aaa|ccc|aac|aaa|aaa|aaa|bbb|ccc|aaa|ccc|bbb|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# ________________________________________________________________________________________________________|_______________
# output before conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|ccc|bbb|bbb|bbb|aaa|bbb|aaa|ccc|ccc|aaa|ccc|aac|aaa|aaa|aaa|bbb|ccc|aaa|ccc|bbb|aaa
# tensor([[-4.4622, -4.0133, -1.1589, 37.8996]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|ccc|bbb|bbb|bbb|aaa|bbb|aaa|ccc|ccc|aaa|ccc|aac|aaa|aaa|aaa|bbb|ccc|aaa|ccc|bbb|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _________________________________________________________________________________________________________c______________
# output before conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|ccc|bbb|bbb|bbb|aaa|bbb|aaa|ccc|ccc|aaa|ccc|aac|aaa|aaa|aaa|bbb|ccc|aaa|ccc|bbb|aaa
# tensor([[  1.0865,   0.0929,   0.5963, -23.0094]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 1.174725
# output after conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|ccc|bbb|ccc|bbb|aaa|bbb|aaa|ccc|ccc|aaa|ccc|ccc|aaa|aaa|aaa|ccc|ccc|ccc|ccc|bbb|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# __________________________________________________________________________________________________________c_____________
# output before conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|aaa|aaa|bbb|ccc|bbb|ccc|bbb|aaa|bbb|aaa|ccc|ccc|aaa|ccc|ccc|aaa|aaa|aaa|ccc|ccc|ccc|ccc|bbb|aaa
# tensor([[  0.7370,  -0.1293,   1.1541, -22.7870]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.660627
# output after conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|ccc|aaa|bbb|ccc|bbb|ccc|bbb|aaa|bbb|aaa|ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|ccc|ccc|ccc|bbb|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# ___________________________________________________________________________________________________________c____________
# output before conditioning:
# |ccc|ccc|bbb|ccc|ccc|aaa|ccc|aaa|bbb|ccc|bbb|ccc|bbb|aaa|bbb|aaa|ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|ccc|ccc|ccc|bbb|aaa
# tensor([[  0.7148,   0.1370,   1.8635, -23.2636]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.402104
# output after conditioning:
# |ccc|ccc|cbc|ccc|ccc|aaa|ccc|aaa|bbb|ccc|bbb|ccc|bbb|aaa|bbb|aaa|ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|ccc|ccc|ccc|bbb|aaa
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# ____________________________________________________________________________________________________________|___________
# output before conditioning:
# |ccc|ccc|cbc|ccc|ccc|aaa|ccc|aaa|bbb|ccc|bbb|ccc|bbb|aaa|bbb|aaa|ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|ccc|ccc|ccc|bbb|aaa
# tensor([[-6.3730, -5.4035,  0.7031, 27.6448]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |ccc|ccc|cbc|ccc|ccc|aaa|ccc|aaa|bbb|ccc|bbb|ccc|bbb|aaa|bbb|aaa|ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|ccc|ccc|ccc|bbb|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _____________________________________________________________________________________________________________a__________
# output before conditioning:
# |ccc|ccc|cbc|ccc|ccc|aaa|ccc|aaa|bbb|ccc|bbb|ccc|bbb|aaa|bbb|aaa|ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|ccc|ccc|ccc|bbb|aaa
# tensor([[ -1.0464,  -1.6061,   1.9264, -26.5636]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 3.050142
# output after conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|aaa|aaa|bbb|ccc|bbb|ccb|bbb|aaa|bbb|aaa|ccc|ccc|aaa|ccc|ccc|aaa|aaa|aaa|ccc|ccc|ccc|ccc|bbb|aaa
# a -> c ... False
# --
# tensor([[  0.0328,  -1.5350,   1.1337, -27.0752]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 1.438730
# output after conditioning:
# |ccc|ccc|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|bbb|aaa|bbb|aaa|ccc|aac|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ______________________________________________________________________________________________________________a_________
# output before conditioning:
# |ccc|ccc|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|bbb|aaa|bbb|aaa|ccc|aac|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# tensor([[  1.9009,  -1.5194,  -0.2151, -27.8879]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.142562
# output after conditioning:
# |ccc|ccc|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|bbb|aaa|bbb|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# _______________________________________________________________________________________________________________a________
# output before conditioning:
# |ccc|ccc|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|bbb|aaa|bbb|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# tensor([[ 2.3714e+00, -1.0754e+00, -7.1536e-03, -2.8665e+01]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.117362
# output after conditioning:
# |ccc|ccc|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|bbb|aaa|bbb|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ________________________________________________________________________________________________________________|_______
# output before conditioning:
# |ccc|ccc|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|bbb|aaa|bbb|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# tensor([[-6.0642, -6.5409, -4.6853, 39.7339]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |ccc|ccc|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|bbb|aaa|bbb|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _________________________________________________________________________________________________________________a______
# output before conditioning:
# |ccc|ccc|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|bbb|aaa|bbb|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# tensor([[ -0.1070,  -0.2864,  -2.0032, -28.0970]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.686060
# output after conditioning:
# |ccc|ccc|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|bbb|aaa|bbb|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# __________________________________________________________________________________________________________________a_____
# output before conditioning:
# |ccc|ccc|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|bbb|aaa|bbb|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|bbb|aaa|aaa|aaa|aaa|aaa
# tensor([[  0.4572,  -0.7821,  -2.0851, -27.9157]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.313544
# output after conditioning:
# |ccc|aac|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|bbb|aaa|bbb|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ___________________________________________________________________________________________________________________a____
# output before conditioning:
# |ccc|aac|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|bbb|aaa|bbb|aaa|ccc|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# tensor([[  0.9407,  -0.7144,  -1.7787, -29.1475]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.228730
# output after conditioning:
# |ccc|aac|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|aaa|aaa|bbb|aaa|aac|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# a -> a ... True
# --------------------------------------------------
# conditioning on:
# ____________________________________________________________________________________________________________________|___
# output before conditioning:
# |ccc|aac|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|aaa|aaa|bbb|aaa|aac|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# tensor([[-2.0361, -5.4512, -5.6623, 25.2869]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.000000
# output after conditioning:
# |ccc|aac|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|aaa|aaa|bbb|aaa|aac|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# | -> | ... True
# --------------------------------------------------
# conditioning on:
# _____________________________________________________________________________________________________________________c__
# output before conditioning:
# |ccc|aac|aaa|aaa|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|aaa|aaa|bbb|aaa|aac|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa|aaa
# tensor([[  2.4841,  -1.3092,  -2.4115, -31.0159]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 4.925184
# output after conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|aaa|aaa|bbb|aaa|bbb|aaa|bbb|aaa|bbb|aaa|ccc|ccc|aaa|aaa|aaa|aaa|aaa|aaa|ccc|aaa|aaa|aaa|aaa|aaa
# c -> a ... False
# --
# tensor([[  1.3941,  -1.2579,  -1.2925, -30.7723]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 2.816402
# output after conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|ccc|bbb|ccc|ccc|ccc|ccc|aaa|ccc|ccc|aaa|ccc|ccc|ccc|ccc|aaa|ccc|ccc|ccc|ccc|ccc|ccc
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# ______________________________________________________________________________________________________________________c_
# output before conditioning:
# |ccc|ccc|aaa|ccc|ccc|aaa|ccc|aaa|ccc|ccc|bbb|ccc|ccc|ccc|ccc|aaa|ccc|ccc|aaa|ccc|ccc|ccc|ccc|aaa|ccc|ccc|ccc|ccc|ccc|ccc
# tensor([[ -0.5866,  -1.2628,   0.7732, -30.3716]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.327344
# output after conditioning:
# |ccc|ccc|aaa|ccc|ccc|ccc|ccc|aaa|ccc|ccc|bbb|ccc|ccc|ccc|ccc|aaa|ccc|ccc|aaa|ccc|ccc|ccc|ccc|aaa|ccc|ccc|ccc|ccc|ccc|ccc
# c -> c ... True
# --------------------------------------------------
# conditioning on:
# _______________________________________________________________________________________________________________________c
# output before conditioning:
# |ccc|ccc|aaa|ccc|ccc|ccc|ccc|aaa|ccc|ccc|bbb|ccc|ccc|ccc|ccc|aaa|ccc|ccc|aaa|ccc|ccc|ccc|ccc|aaa|ccc|ccc|ccc|ccc|ccc|ccc
# tensor([[ -0.5586,  -1.1376,   1.3144, -31.4117]], device='cuda:0',
#        grad_fn=<AddmmBackward0>)
# Loss: 0.214928
# output after conditioning:
# |ccc|ccc|aaa|ccc|ccc|ccc|ccc|aaa|ccc|ccc|bbb|ccc|ccc|ccc|ccc|aaa|ccc|ccc|aaa|ccc|ccc|ccc|ccc|aaa|ccc|ccc|ccc|ccc|ccc|ccc
# c -> c ... True
